# %% [markdown]
# ### **BREVE INTRO A LOS DECORADORES**

# %%
# %pip install flask jsonify
# Out:
# Collecting flask
#   Downloading flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting jsonify
#   Downloading jsonify-0.5.tar.gz (1.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: blinker>=1.9.0 in c:\users\rns_2\appdata\local\programs\python\python311\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\rns_2\appdata\local\programs\python\python311\lib\site-packages (from flask) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\rns_2\appdata\local\programs\python\python311\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\rns_2\appdata\local\programs\python\python311\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\rns_2\appdata\local\programs\python\python311\lib\site-packages (from flask) (3.0.3)
# Collecting werkzeug>=3.1.0 (from flask)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: colorama in c:\users\rns_2\appdata\roaming\python\python311\site-packages (from click>=8.1.3->flask) (0.4.6)
# Downloading flask-3.1.3-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/103.4 kB ? eta -:--:--
#    ----------------------- --------------- 61.4/103.4 kB 825.8 kB/s eta 0:00:01
#    ---------------------------------------- 103.4/103.4 kB 1.2 MB/s eta 0:00:00
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.5 kB ? eta -:--:--
#    ---------------------------------------- 226.5/226.5 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: jsonify
#   Building wheel for jsonify (setup.py): started
#   Building wheel for jsonify (setup.py): finished with status 'done'
#   Created wheel for jsonify: filename=jsonify-0.5-py3-none-any.whl size=1571 sha256=cb6b303d77ed6865ba203350dfcbfb1b20c5fc350f2ff330859abe5959b87773
#   Stored in directory: c:\users\rns_2\appdata\local\pip\cache\wheels\8b\0b\70\cd8a2f72ec6e8dbab2d7fffe3e8a545f4d152255cc7e8541f5
# Successfully built jsonify
# Installing collected packages: jsonify, werkzeug, flask
# Successfully installed flask-3.1.3 jsonify-0.5 werkzeug-3.1.8
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Los decoradores en Python son una característica poderosa y flexible que permite modificar o extender el comportamiento de funciones o métodos de forma transparente. Los decoradores son funciones que toman otra función o método como argumento y retornan una nueva función o método con algún tipo de modificación.
#
# Aquí hay tres ejemplos simples de cómo usar decoradores en Python:
#
# 1. **Registro de tiempo de ejecución:**
# Supongamos que queremos medir el tiempo que tarda una función en ejecutarse. Podemos crear un decorador para esto:

# %%
import time

def calcular_tiempo_ejecucion(funcion):
    def wrapper(*args, **kwargs):
        inicio = time.time()
        resultado = funcion(*args, **kwargs)
        fin = time.time()
        print(f"Tiempo de ejecución de {funcion.__name__}: {fin - inicio} segundos")
        return resultado
    return wrapper

@calcular_tiempo_ejecucion
def mi_funcion():
    # Supongamos que esta es una función que hace algo que queremos medir
    time.sleep(2)
    print("Función ejecutada")

mi_funcion()
# Out:
# Función ejecutada
# Tiempo de ejecución de mi_funcion: 2.001221179962158 segundos

# %% [markdown]
# Este decorador `calcular_tiempo_ejecucion` envuelve la función `mi_funcion` y calcula el tiempo que tarda en ejecutarse.
#
# 2. **Validación de entrada:**
# Podemos usar un decorador para validar los argumentos de una función:

# %%
def validar_argumentos(funcion):
    def wrapper(*args, **kwargs):
        for arg in args:
            if not isinstance(arg, int):
                raise TypeError("Los argumentos deben ser enteros")
        return funcion(*args, **kwargs)
    return wrapper

@validar_argumentos
def suma(a, b):
    return a + b

# %%
# Esto funcionará bien
print(suma(3, 5))
# Out:
# 8

# %%
# Esto lanzará un error
print(suma(3, "5"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Esto lanzará un error
# ----> 2 print(suma(3, "5"))
#
# Cell In[3], line 5, in validar_argumentos.<locals>.wrapper(*args, **kwargs)
#       3 for arg in args:
#       4     if not isinstance(arg, int):
# ----> 5         raise TypeError("Los argumentos deben ser enteros")
#       6 return funcion(*args, **kwargs)
#
# TypeError: Los argumentos deben ser enteros

# %% [markdown]
# Este decorador `validar_argumentos` asegura que todos los argumentos pasados a la función `suma` sean enteros.
#
# 3. **Autenticación de usuario:**
# Supongamos que queremos asegurarnos de que solo los usuarios autenticados puedan acceder a ciertas funciones:

# %%
usuario_autenticado = False

def requerir_autenticacion(funcion):
    def wrapper(*args, **kwargs):
        if usuario_autenticado:
            return funcion(*args, **kwargs)
        else:
            raise PermissionError("Debe iniciar sesión para acceder a esta función")
    return wrapper

@requerir_autenticacion
def funcion_privada():
    print("Esta es una función privada")

# %%
# Intentamos llamar a la función sin autenticarnos
funcion_privada()  # Esto lanzará un error
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Intentamos llamar a la función sin autenticarnos
# ----> 2 funcion_privada()  # Esto lanzará un error
#
# Cell In[6], line 8, in requerir_autenticacion.<locals>.wrapper(*args, **kwargs)
#       6     return funcion(*args, **kwargs)
#       7 else:
# ----> 8     raise PermissionError("Debe iniciar sesión para acceder a esta función")
#
# PermissionError: Debe iniciar sesión para acceder a esta función

# %%
# Simulamos autenticación
usuario_autenticado = True

# Ahora podemos llamar a la función sin problemas
funcion_privada()
# Out:
# Esta es una función privada

# %% [markdown]
# Este decorador `requerir_autenticacion` verifica si el usuario está autenticado antes de permitir el acceso a la función `funcion_privada`.
#
# Estos son solo ejemplos básicos para ilustrar el concepto de decoradores en Python. Se pueden crear decoradores mucho más complejos para realizar una variedad de tareas útiles, como el manejo de errores, la caché de resultados, la transformación de datos, entre otros.
