# %% [markdown]
# # Pyspark Dataframes
# ### Qué vamos a ver
# - PySpark Dataframe
# - Leer un dataset
# - Comprobar los Datatypes de las columnas (Schema)
# - Seleccionar columnas e indexarlas
# - Check Describe option similar to Pandas
# - Añadir columnas
# - Eliminar columnas
# - Renombrar Columnas

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 spark = SparkSession.builder.appName('Practise').getOrCreate()
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\java_gateway.py:108, in launch_gateway(conf, popen_kwargs)
#     106 # Wait for the file to appear, or for the process to exit, whichever happens first.
#     107 while not proc.poll() and not os.path.isfile(conn_info_file):
# --> 108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
#     111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#
# KeyboardInterrupt:

# %%
spark

# %% [markdown]
# LEEMOS EL DATASET

# %%
df_pyspark = spark.read.option('header', 'true').csv('data/test1.csv')
df_pyspark.show()

# %% [markdown]
# COMPROBAMOS EL TIPO DE DATOS QUE TENEMOS

# %%
df_pyspark.printSchema()

# %%
df_pyspark = spark.read.csv('data/test1.csv', header=True, inferSchema=True) # equivalente a spark.read.option('header', 'true').option('inferSchema', 'true').csv('data/test1.csv')
df_pyspark.show()

# %%
df_pyspark.printSchema()

# %%
# también podríamos pasarle el esquema manualmente, muy útil para formatos timestamps por ejemplo

# Ejemplo:
# data_schema = [StructField("time", TimestampType(), True),
#                StructField("action", StringType(), True)]

# df_pyspark = spark.read.format("csv").option("header", True).schema(data_schema).load("file.csv")

# %% [markdown]
# VOLVEMOS A COMPROBAR LOS DATOS

# %%
df_pyspark.printSchema()

# %%
df_pyspark.dtypes

# %%
df_pyspark.describe().show()

# %% [markdown]
# MOSTRAMOS LOS PRIMEROS VALORES

# %%
df_pyspark.head(3)

# %% [markdown]
# #### SELECCIONAR COLUMNAS (select)

# %% [markdown]
# SELECCIONAR COLUMNAS POR NOMBRE

# %%
df_pyspark.select(['Name', 'Experience']).show()

# %%
df_pyspark['Name']

# %%
df_pyspark.select(['Name']).distinct().show()
#distinct nos muestra los valores únicos

# %% [markdown]
# SELECCIONAR COLUMNAS POR ÍNDICE

# %% [markdown]
# No existe el comando como tal, pero podemos trampearlo de esta forma:

# %%
df_pyspark.columns #columnas

# %%
df_pyspark.count() #filas

# %%
# El método columns nos devuelve una lista de las columnas que le indiquemos por índice

df_pyspark.columns[:3]

# %%
# De este modo, podemos obtener de forma indirecta las columnas por índice

df_pyspark.select(df_pyspark.columns[:3]).show(3)

# %% [markdown]
# #### AÑADIR, ELIMINAR Y RENOMBRAR COLUMNAS

# %% [markdown]
# AÑADIR COLUMNAS

# %%
df_pyspark_new_column = df_pyspark.withColumn('Experience after 2 years', df_pyspark['Experience']+2) # Nombre de la columna y valores de la columna

# %%
df_pyspark_new_column.show()

# %% [markdown]
# ELIMINAR COLUMNAS

# %%
df_pyspark_drop_column = df_pyspark.drop('Experience after 2 years')

# %%
df_pyspark_drop_column.show()

# %% [markdown]
# RENOMBRAR COLUMNAS

# %%
df_pyspark.withColumnRenamed('Name', 'New_name').show()
