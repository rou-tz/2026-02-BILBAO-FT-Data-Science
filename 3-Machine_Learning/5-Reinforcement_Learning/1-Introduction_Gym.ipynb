# %% [markdown]
# ## Intro Aprendizaje por Refuerzo

# %% [markdown]
# Considera el escenario de enseñarle nuevos trucos a un perro. El perro no entiende nuestro lenguaje, así que no podemos decirle qué hacer. En cambio, seguimos una estrategia diferente. Emulamos una situación (o una señal), y el perro intenta responder de muchas maneras diferentes. Si la respuesta del perro es la deseada, lo recompensamos con golosinas. Ahora, adivina qué, la próxima vez que el perro se enfrenta a la misma situación, ejecuta una acción similar con aún más entusiasmo esperando más comida. Esto es como aprender "qué hacer" a partir de experiencias positivas. De manera similar, los perros tienden a aprender qué no hacer cuando se enfrentan a experiencias negativas.

# %% [markdown]
# ## Entendiendo cómo funciona el Aprendizaje por Refuerzo
#
# En un sentido más amplio, así es como funciona el Aprendizaje por Refuerzo:
#
# * Tu perro es un "agente" que está expuesto al entorno. El entorno podría ser tu casa, contigo.
# * Las situaciones que encuentran son análogas a un estado. Un ejemplo de un estado podría ser tu perro de pie y tú usando una palabra específica con cierto tono en tu sala de estar.
# * Nuestros agentes reaccionan realizando una acción para pasar de un "estado" a otro "estado"; por ejemplo, tu perro pasa de estar de pie a sentarse.
# * Después de la transición, pueden recibir una recompensa o una penalización a cambio. ¡Les das una golosina! O un "No" como penalización.
# * La política es la estrategia de elegir una acción dada un estado en espera de mejores resultados.

# %% [markdown]
# El Aprendizaje por Refuerzo se encuentra entre el espectro del Aprendizaje Supervisado y el No Supervisado, y hay algunas cosas importantes que tener en cuenta:
#
# #### No siempre es beneficioso ser codicioso
#
# **Ser codicioso no siempre funciona:**
#
# * Hay cosas que son fáciles de hacer para obtener una gratificación instantánea, y hay cosas que proporcionan recompensas a largo plazo. El objetivo no es ser codicioso buscando las recompensas inmediatas, sino optimizar las recompensas máximas durante todo el entrenamiento.
#
# #### La secuencia importa en el Aprendizaje por Refuerzo
#
# **La secuencia importa en el Aprendizaje por Refuerzo:**
#
# * La recompensa del agente no solo depende del estado actual, sino de toda la historia de estados. A diferencia del aprendizaje supervisado y no supervisado, el tiempo es importante aquí.

# %% [markdown]
# ## El proceso

# %% [markdown]
# <img src="./img/Reinforcement-Learning-Animation.gif" alt="drawing" width="650"/>

# %% [markdown]
# En cierto sentido, el Aprendizaje por Refuerzo es la ciencia de tomar decisiones óptimas utilizando experiencias. Desglosándolo, el proceso de Aprendizaje por Refuerzo involucra estos pasos simples:
#
# 1. Observación del entorno.
# 2. Decidir cómo actuar utilizando alguna estrategia.
# 3. Actuar en consecuencia.
# 4. Recibir una recompensa o penalización.
# 5. Aprender de las experiencias y refinar nuestra estrategia.
# 6. Iterar hasta encontrar una estrategia óptima.
#
# Ahora vamos a entender el Aprendizaje por Refuerzo desarrollando un agente para aprender a jugar un juego automáticamente por sí mismo.

# %% [markdown]
# ## Comenzando con Gym
#
# Gym es un conjunto de herramientas para desarrollar y comparar algoritmos de aprendizaje por refuerzo. No hace suposiciones sobre la estructura de tu agente y es compatible con cualquier biblioteca de cálculo numérico, como TensorFlow o Theano.
#
# La biblioteca Gym es una colección de problemas de prueba, o entornos, que puedes usar para desarrollar tus algoritmos de aprendizaje por refuerzo. Estos entornos tienen una interfaz compartida, lo que te permite escribir algoritmos generales.

# %%
#%pip install gymnasium[classic_control]
#%pip install pygame

# %%
#!pip install numpy==1.23.5

# %% [markdown]
# ## Entornos
#
# Aquí tienes un ejemplo mínimo para comenzar a ejecutar algo. Esto ejecutará una instancia del entorno CartPole-v0 durante 1000 pasos de tiempo, representando el entorno en cada paso.

# %% [markdown]
#  Consiste en equilibrar un poste (péndulo) montado en la parte superior de un carrito móvil:
#  * El **objetivo** es mantener el poste en posición vertical mientras el carrito se mueve hacia adelante y hacia atrás en una pista.
#  * El **agente** (o jugador) tiene dos acciones disponibles en cada paso de tiempo: empujar el carrito hacia la izquierda o hacia la derecha.
#  * El **desafío** radica en tomar decisiones adecuadas para evitar que el poste caiga mientras se mueve el carrito.
#
#  Este problema es un ejemplo comúnmente utilizado para probar algoritmos de aprendizaje por refuerzo debido a su simplicidad y naturaleza desafiante.

# %% [markdown]
# https://gymnasium.farama.org/api/env/

# %%
import gymnasium as gym
import warnings
warnings.filterwarnings("ignore")
import time
import numpy as np

# %% [markdown]
# Crea un entorno de simulación llamado MountainCar-v0.
# Este es un entorno clásico en gym en el que un coche debe moverse hacia arriba de una colina empinada.
# El objetivo es aplicar fuerza en las direcciones izquierda o derecha para ganar impulso suficiente y alcanzar la cima.

# %%
env = gym.make('CartPole-v0')

# %% [markdown]
# Reinicia el entorno a su estado inicial.
# Esto es útil para comenzar una nueva simulación. Devuelve el estado inicial del entorno.

# %%
env.reset()
# Out:
# (array([ 0.02692763,  0.04366515, -0.0034578 , -0.0116048 ], dtype=float32),
#  {})

# %% [markdown]
# A continuación: se ejecuta un bucle con 300 pasos dentro del entorno.

# %% [markdown]
# ``env.render()`` dibuja el entorno en una ventana gráfica para que puedas visualizar lo que está sucediendo (por ejemplo, el carro moviéndose).

# %% [markdown]
# ``env.action_space.sample()``
# Toma una acción aleatoria en el espacio de acciones del entorno. En este caso, las acciones posibles son:
#
# * 0: Aplicar fuerza hacia la izquierda.
# * 1: No aplicar fuerza.
# * 2: Aplicar fuerza hacia la derecha.

# %%
#for i in range(300):
#    env.render()
#    time.sleep(0.1)
#    env.step(env.action_space.sample()) # take a random action
#env.close()

# %%
#numpy.__version__

# %%
import gymnasium as gym
import warnings
import numpy

warnings.filterwarnings("ignore")

# Crear el entorno
env = gym.make('MountainCar-v0')
env.reset()

# Loop para ejecutar pasos en el entorno
for i in range(300):
    env.render()  # Renderizar el entorno
    env.step(env.action_space.sample())  # Tomar una acción aleatoria

env.close()

# %%
#numpy.__version__

# %% [markdown]
# Normalmente, terminaremos la simulación antes de que el carrito-péndulo tenga permitido salir de la pantalla. Más sobre eso después. Por ahora, por favor ignora la advertencia sobre llamar a `step()` aunque este entorno ya haya devuelto `done = True`.
#
# Si deseas ver otros entornos en acción, intenta reemplazar `CartPole-v0` arriba con algo como `MountainCar-v0`, `MsPacman-v0` (requiere la dependencia de Atari), o `Hopper-v1` (requiere las dependencias de MuJoCo). Todos los entornos descienden de la clase base `Env`.
#
# Ten en cuenta que si te faltan dependencias, deberías recibir un mensaje de error útil que te diga qué te falta. (Avísanos si alguna dependencia te causa problemas sin una instrucción clara para solucionarlo). Instalar una dependencia faltante generalmente es bastante simple. También necesitarás una licencia de MuJoCo para `Hopper-v1`.

# %% [markdown]
# ## Observaciones
#
# Si queremos hacer algo mejor que tomar acciones aleatorias en cada paso, probablemente sería bueno saber realmente qué están haciendo nuestras acciones en el entorno.
#
# La función `step` del entorno devuelve exactamente lo que necesitamos. De hecho, `step` devuelve cuatro valores. Estos son:
#
# * `observation` (object): un objeto específico del entorno que representa tu observación del entorno. Por ejemplo, datos de píxeles de una cámara, ángulos de articulación y velocidades de articulación de un robot, o el estado del tablero en un juego de mesa.
# * `reward` (float): cantidad de recompensa lograda por la acción anterior. La escala varía entre entornos, pero el objetivo es siempre aumentar tu recompensa total.
# * `done` (bool): si es hora de restablecer el entorno nuevamente. La mayoría (pero no todos) de las tareas están divididas en episodios bien definidos, y `done` siendo True indica que el episodio ha terminado. (Por ejemplo, tal vez el poste se inclinó demasiado, o perdiste tu última vida).
# * `truncated` (bool): True si el episodio se trunca debido a un límite de tiempo o una razón que no está definida.
# * `info` (dict): información de diagnóstico útil para la depuración. A veces puede ser útil para el aprendizaje (por ejemplo, podría contener las probabilidades crudas detrás del último cambio de estado del entorno). Sin embargo, no se permite usar esto para el aprendizaje en las evaluaciones oficiales de tu agente.
#
# Esto es simplemente una implementación del clásico "bucle agente-entorno". En cada paso de tiempo, el agente elige una acción, y el entorno devuelve una observación y una recompensa.

# %%
env = gym.make('MountainCar-v0')

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# ## Espacio de Acciones
#
# Hay 3 acciones discretas determinísticas:
#
# | Num | Observación          | Valor | Unidad       |
# |-----|----------------------|-------|--------------|
# | 0   | Acelerar a la izquierda | Inf   | posición (m) |
# | 1   | No acelerar              | Inf   | posición (m) |
# | 2   | Acelerar a la derecha    | Inf   | posición (m) |

# %%
# env = gym.make('MountainCar-v0', render_mode='human')
print(env.observation_space.shape)
# Out:
# (2,)

# %% [markdown]
# ## Espacio de Observación
#
# La observación es un ndarray con forma (2,), donde los elementos corresponden a lo siguiente:
#
# | Num | Observación                    | Mínimo | Máximo | Unidad        |
# |-----|--------------------------------|--------|--------|---------------|
# | 0   | posición del coche a lo largo del eje x | -Inf   | Inf    | posición (m) |
# | 1   | velocidad del coche             | -Inf   | Inf    | velocidad (m) |

# %%
import numpy as np
np.random.choice(np.array([1,2,3]))
# Out:
# np.int64(2)

# %%
# import gym
env = gym.make('MountainCar-v0', render_mode='human')
for i_episode in range(5):
    # Reset del entorno
    print("Intento", i_episode)
    observation = env.reset()
    for t in range(10000):
        if t % 10 == 0:
            print("Accion", t)
            print("Observación", observation)
        # Visualizar ejercicio
        env.render()
        # Print del estado
        # print(observation)
        # Guarda en la variable action una de las acciones posibles elegida al azar
        action = env.action_space.sample()
        # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
        # que nos indica que ha alcanzado su objetivo e info debug
        observation, reward, done, truncated, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Intento 0
# Accion 0
# Observación (array([-0.55633867,  0.        ], dtype=float32), {})
# Accion 10
# Observación [-0.5264553   0.00466014]
# Accion 20
# Observación [-0.47445524  0.00301063]
# Accion 30
# Observación [-0.48637277 -0.00371444]
# Accion 40
# Observación [-0.527722   -0.00306997]
# Accion 50
# Observación [-0.5756273  -0.00409175]
# Accion 60
# Observación [-0.5825874  -0.00085624]
# Accion 70
# Observación [-0.5739535   0.00127862]
# Accion 80
# Observación [-0.5543662   0.00248183]
# Accion 90
# Observación [-0.5120738   0.00333652]
# Accion 100
# Observación [-0.48959267  0.00162869]
# Accion 110
# Observación [-0.4741883  -0.00167228]
# Accion 120
# Observación [-0.49558866 -0.00384875]
# Accion 130
# Observación [-0.5219464  -0.00196279]
# Accion 140
# Observación [-0.5615352  -0.00497318]
# Accion 150
# Observación [-0.59817886 -0.00273042]
# Accion 160
# Observación [-0.56493837  0.00833748]
# Accion 170
# Observación [-0.50241077  0.00392222]
# Accion 180
# Observación [-0.48074606 -0.00065495]
# Accion 190
# Observación [-0.5175619  -0.00382616]
# Accion 200
# Observación [-0.5702087  -0.00335767]
# Accion 210
# Observación [-0.5767276  0.0015825]
# Accion 220
# Observación [-0.5324963   0.00625833]
# Accion 230
# Observación [-0.46770296  0.006844  ]
# Accion 240
# Observación [-0.41338685  0.00254486]
# Accion 250
# Observación [-0.44231328 -0.00604719]
# Accion 260
# Observación [-0.53226423 -0.01031859]
# Accion 270
# Observación [-0.5932823  -0.00322716]
# Accion 280
# Observación [-0.59535706  0.00351926]
# Accion 290
# Observación [-0.54330343  0.00526961]
# Accion 300
# Observación [-0.50236684  0.00319093]
# Accion 310
# Observación [-0.4854524   0.00101227]
# Accion 320
# Observación [-4.77895081e-01 -1.02140344e-04]
# Accion 330
# Observación [-0.4700645   0.00114517]
# Accion 340
# Observación [-0.47949058 -0.00155443]
# Accion 350
# Observación [-0.51596403 -0.007101  ]
# Accion 360
# Observación [-0.5539548  -0.00192478]
# Accion 370
# Observación [-0.568447   -0.00209811]
# Accion 380
# Observación [-0.56531817  0.00357385]
# Accion 390
# Observación [-0.48468226  0.0103028 ]
# Accion 400
# Observación [-0.39769542  0.00624097]
# Accion 410
# Observación [-0.37593457 -0.00420291]
# Accion 420
# Observación [-0.46318784 -0.0093938 ]
# Accion 430
# Observación [-0.57353926 -0.00798798]
# Accion 440
# Observación [-0.6045486   0.00129759]
# Accion 450
# Observación [-0.5610042   0.00500799]
# Accion 460
# Observación [-0.4899133   0.00868641]
# Accion 470
# Observación [-0.44124103  0.00328355]
# Accion 480
# Observación [-0.41017714  0.00326855]
# Accion 490
# Observación [-0.4232555  -0.00634304]
# Accion 500
# Observación [-0.5213054  -0.01407634]
# Accion 510
# Observación [-0.62660956 -0.00741693]
# Accion 520
# Observación [-0.6497797   0.00465703]
# Accion 530
# Observación [-0.54140323  0.01511574]
# Accion 540
# Observación [-0.4035076   0.01270312]
# Accion 550
# Observación [-0.33821824  0.00232579]
# Accion 560
# Observación [-0.39189228 -0.00989436]
# Accion 570
# Observación [-0.54394    -0.01697655]
# Accion 580
# Observación [-0.68142617 -0.00844114]
# Accion 590
# Observación [-7.0974952e-01  2.4624026e-04]
# Accion 600
# Observación [-0.6525142   0.01245829]
# Accion 610
# Observación [-0.5169656  0.0145043]
# Accion 620
# Observación [-0.3663972   0.01069461]
# Accion 630
# Observación [-0.31591177 -0.00186087]
# Accion 640
# Observación [-0.4102763  -0.01217373]
# Accion 650
# Observación [-0.5527304  -0.01379805]
# Accion 660
# Observación [-6.2579638e-01 -3.6004954e-04]
# Accion 670
# Observación [-0.58732545  0.00736604]
# Accion 680
# Observación [-0.48993036  0.0089311 ]
# Accion 690
# Observación [-0.42757195  0.0040419 ]
# Accion 700
# Observación [-0.4196794  -0.00264218]
# Accion 710
# Observación [-0.47308016 -0.00576861]
# Accion 720
# Observación [-0.5576432  -0.00879864]
# Accion 730
# Observación [-0.58637625 -0.00078863]
# Accion 740
# Observación [-0.5764358   0.00281324]
# Accion 750
# Observación [-0.5521662   0.00183621]
# Accion 760
# Observación [-0.53008616  0.00336869]
# Accion 770
# Observación [-0.50549567 -0.00135626]
# Accion 780
# Observación [-0.5481755  -0.00545206]
# Accion 790
# Observación [-0.6182134  -0.00527674]
# Accion 800
# Observación [-0.6503385  -0.00097318]
# Accion 810
# Observación [-0.6103283   0.00767986]
# Accion 820
# Observación [-0.5243193   0.01033923]
# Accion 830
# Observación [-0.44270828  0.00748   ]
# Accion 840
# Observación [-0.41041005 -0.00109793]
# Accion 850
# Observación [-0.4389743  -0.00575653]
# Accion 860
# Observación [-0.55208343 -0.01157318]
# Accion 870
# Observación [-0.6461864  -0.00583682]
# Accion 880
# Observación [-0.65799755  0.00305676]
# Accion 890
# Observación [-0.57582676  0.01185773]
# Accion 900
# Observación [-0.42359748  0.0148127 ]
# Accion 910
# Observación [-0.3013255   0.00838047]
# Accion 920
# Observación [-0.31399766 -0.0074539 ]
# Accion 930
# Observación [-0.45708936 -0.01646885]
# Accion 940
# Observación [-0.63751966 -0.01747384]
# Accion 950
# Observación [-0.7306607  -0.00143342]
# Accion 960
# Observación [-0.66822124  0.01198281]
# Accion 970
# Observación [-0.5029225   0.01754029]
# Accion 980
# Observación [-0.375821    0.00932614]
# Accion 990
# Observación [-0.32229048  0.0016436 ]
# Accion 1000
# Observación [-0.39319223 -0.01443677]
# Accion 1010
# Observación [-0.5699528  -0.01733966]
# Accion 1020
# Observación [-0.67558587 -0.00461401]
# Accion 1030
# Observación [-0.6869625   0.00111089]
# Accion 1040
# Observación [-0.62936217  0.00955074]
# Accion 1050
# Observación [-0.50052255  0.01444703]
# Accion 1060
# Observación [-0.38840804  0.00859626]
# Accion 1070
# Observación [-0.36032754 -0.00385055]
# Accion 1080
# Observación [-0.43866345 -0.0138195 ]
# Accion 1090
# Observación [-0.6040535  -0.01791352]
# Accion 1100
# Observación [-0.7171252  -0.00455976]
# Accion 1110
# Observación [-0.70096904  0.00730025]
# Accion 1120
# Observación [-0.5801176   0.01577097]
# Accion 1130
# Observación [-0.42078733  0.01360321]
# Accion 1140
# Observación [-0.3297644   0.00684262]
# Accion 1150
# Observación [-0.33590695 -0.00626913]
# Accion 1160
# Observación [-0.4282318  -0.01314473]
# Accion 1170
# Observación [-0.5909239  -0.01700692]
# Accion 1180
# Observación [-0.7202286  -0.01049932]
# Accion 1190
# Observación [-0.7670461   0.00127678]
# Accion 1200
# Observación [-0.68366534  0.01432289]
# Accion 1210
# Observación [-0.49906328  0.02141925]
# Accion 1220
# Observación [-0.32297054  0.01328001]
# Accion 1230
# Observación [-0.26352006 -0.0022043 ]
# Accion 1240
# Observación [-0.36347783 -0.01488829]
# Accion 1250
# Observación [-0.56246173 -0.02258874]
# Accion 1260
# Observación [-0.74432063 -0.00993443]
# Accion 1270
# Observación [-0.7612612   0.00655871]
# Accion 1280
# Observación [-0.6205565   0.01761435]
# Accion 1290
# Observación [-0.43741846  0.01543223]
# Accion 1300
# Observación [-0.33026746  0.00596799]
# Accion 1310
# Observación [-0.33209378 -0.00634949]
# Accion 1320
# Observación [-0.4796817  -0.01915479]
# Accion 1330
# Observación [-0.6424325  -0.01361584]
# Accion 1340
# Observación [-0.73203886 -0.00262551]
# Accion 1350
# Observación [-0.6666393   0.01191873]
# Accion 1360
# Observación [-0.5279428   0.01395055]
# Accion 1370
# Observación [-0.37629375  0.01316651]
# Accion 1380
# Observación [-0.28182557  0.00528157]
# Accion 1390
# Observación [-0.32013425 -0.01000212]
# Accion 1400
# Observación [-0.49211496 -0.02068328]
# Accion 1410
# Observación [-0.69409126 -0.01607012]
# Accion 1420
# Observación [-0.7759587   0.00130088]
# Accion 1430
# Observación [-0.67844653  0.0145371 ]
# Accion 1440
# Observación [-0.48515907  0.01865902]
# Accion 1450
# Observación [-0.28920168  0.01535592]
# Accion 1460
# Observación [-0.24005641 -0.00482792]
# Accion 1470
# Observación [-0.3797548  -0.01983355]
# Accion 1480
# Observación [-0.59992945 -0.02236912]
# Accion 1490
# Observación [-0.7617973  -0.00768567]
# Accion 1500
# Observación [-0.762967    0.00643348]
# Accion 1510
# Observación [-0.6293      0.01558654]
# Accion 1520
# Observación [-0.4380215   0.02033583]
# Accion 1530
# Observación [-0.31069145  0.00613783]
# Accion 1540
# Observación [-0.30800286 -0.00654908]
# Accion 1550
# Observación [-0.44551012 -0.02036223]
# Accion 1560
# Observación [-0.6515862  -0.02042885]
# Accion 1570
# Observación [-0.76927584 -0.00374991]
# Accion 1580
# Observación [-0.719216    0.00931316]
# Accion 1590
# Observación [-0.5678172   0.01706987]
# Accion 1600
# Observación [-0.38914022  0.0163101 ]
# Accion 1610
# Observación [-0.2970545  0.0041904]
# Accion 1620
# Observación [-0.3443123  -0.01313364]
# Accion 1630
# Observación [-0.5395907  -0.02231899]
# Accion 1640
# Observación [-0.74853575 -0.01582802]
# Accion 1650
# Observación [-0.79903203  0.00389635]
# Accion 1660
# Observación [-0.68709284  0.01604907]
# Accion 1670
# Observación [-0.4830417   0.02260111]
# Accion 1680
# Observación [-0.2877848   0.01375714]
# Accion 1690
# Observación [-0.21816655 -0.00286596]
# Accion 1700
# Observación [-0.33675584 -0.01869237]
# Accion 1710
# Observación [-0.569206   -0.02604528]
# Accion 1720
# Observación [-0.77182233 -0.01561784]
# Accion 1730
# Observación [-0.8111562   0.00831065]
# Accion 1740
# Observación [-0.61782     0.02619242]
# Accion 1750
# Observación [-0.3475653   0.02412633]
# Accion 1760
# Observación [-0.20214929  0.0058645 ]
# Accion 1770
# Observación [-0.23629981 -0.01064911]
# Accion 1780
# Observación [-0.47171912 -0.03131178]
# Accion 1790
# Observación [-0.7538557 -0.0222929]
# Accion 1800
# Observación [-0.8719659  -0.00286437]
# Accion 1810
# Observación [-0.75145936  0.02332494]
# Accion 1820
# Observación [-0.4535165   0.03145579]
# Accion 1830
# Observación [-0.18923362  0.01758973]
# Accion 1840
# Observación [-0.12292579 -0.00307852]
# Accion 1850
# Observación [-0.26980138 -0.02468044]
# Accion 1860
# Observación [-0.5819288  -0.03213279]
# Accion 1870
# Observación [-0.8389121  -0.01819496]
# Accion 1880
# Observación [-0.91674155  0.00412686]
# Accion 1890
# Observación [-0.7360457   0.02674092]
# Accion 1900
# Observación [-0.4406311   0.02963291]
# Accion 1910
# Observación [-0.18582985  0.01831574]
# Accion 1920
# Observación [-0.12571882 -0.00239304]
# Accion 1930
# Observación [-0.28453985 -0.02466802]
# Accion 1940
# Observación [-0.58384264 -0.03157472]
# Accion 1950
# Observación [-0.8650724  -0.02004577]
# Accion 1960
# Observación [-0.9313384   0.00288824]
# Accion 1970
# Observación [-0.770599  0.024543]
# Accion 1980
# Observación [-0.43059915  0.03680436]
# Accion 1990
# Observación [-0.10761648  0.02544908]
# Accion 2000
# Observación [ 0.01892043 -0.00126217]
# Accion 2010
# Observación [-0.12169734 -0.02402711]
# Accion 2020
# Observación [-0.469075   -0.03977649]
# Accion 2030
# Observación [-0.8591365  -0.03287965]
# Accion 2040
# Observación [-1.0805781  -0.01194306]
# Accion 2050
# Observación [-1.0891844   0.00772696]
# Accion 2060
# Observación [-0.8668598   0.03314185]
# Accion 2070
# Observación [-0.4657298  0.0425499]
# Accion 2080
# Observación [-0.13630238  0.02474778]
# Accion 2090
# Observación [0.00539852 0.00329135]
# Accion 2100
# Observación [-0.07106935 -0.01764617]
# Accion 2110
# Observación [-0.4057494  -0.04238378]
# Accion 2120
# Observación [-0.82344425 -0.03494239]
# Accion 2130
# Observación [-1.0405675  -0.00966494]
# Accion 2140
# Observación [-0.99576586  0.01430778]
# Accion 2150
# Observación [-0.7256179   0.03707448]
# Accion 2160
# Observación [-0.30790064  0.03911645]
# Accion 2170
# Observación [-0.0099933   0.01964545]
# Accion 2180
# Observación [ 0.03960469 -0.00718434]
# Accion 2190
# Observación [-0.2178199  -0.03834354]
# Accion 2200
# Observación [-0.6749642 -0.0465911]
# Accion 2210
# Observación [-1.0543971  -0.02855489]
# Accion 2220
# Observación [-1.1962702  0.0024879]
# Accion 2230
# Observación [-1.0454863   0.02616829]
# Accion 2240
# Observación [-0.6500441   0.05019999]
# Accion 2250
# Observación [-0.15763709  0.04114093]
# Accion 2260
# Observación [0.12374498 0.01596644]
# Accion 2270
# Observación [ 0.1680174  -0.00420013]
# Accion 2280
# Observación [-0.00398246 -0.02565485]
# Accion 2290
# Observación [-0.3638522 -0.0410119]
# Accion 2300
# Observación [-0.80011225 -0.03927602]
# Accion 2310
# Observación [-1.0553628  -0.01532271]
# Accion 2320
# Observación [-1.0738223  0.0095141]
# Accion 2330
# Observación [-0.83817834  0.03364882]
# Accion 2340
# Observación [-0.4535038   0.03967667]
# Accion 2350
# Observación [-0.14765832  0.02174208]
# Accion 2360
# Observación [-0.05074478  0.00068454]
# Accion 2370
# Observación [-0.20724829 -0.02805695]
# Accion 2380
# Observación [-0.5767993  -0.03897691]
# Accion 2390
# Observación [-0.9222879  -0.02956147]
# Accion 2400
# Observación [-1.0849199  -0.00596812]
# Accion 2410
# Observación [-1.0109684   0.01990922]
# Accion 2420
# Observación [-0.67631894  0.04294289]
# Accion 2430
# Observación [-0.24489805  0.0364746 ]
# Accion 2440
# Observación [-0.01266902  0.01054878]
# Accion 2450
# Observación [-0.06061146 -0.01841717]
# Accion 2460
# Observación [-0.3624977  -0.03819091]
# Accion 2470
# Observación [-0.7694446  -0.03643687]
# Accion 2480
# Observación [-1.0260713  -0.01527743]
# Accion 2490
# Observación [-1.0445219   0.01068922]
# Accion 2500
# Observación [-0.794891    0.03620841]
# Accion 2510
# Observación [-0.37173897  0.04313121]
# Accion 2520
# Observación [-0.0480946  0.0227027]
# Accion 2530
# Observación [ 0.02588095 -0.00122703]
# Accion 2540
# Observación [-0.12931763 -0.02797817]
# Accion 2550
# Observación [-0.5127903  -0.04102723]
# Accion 2560
# Observación [-0.86825013 -0.02803526]
# Accion 2570
# Observación [-1.0351481  -0.00513395]
# Accion 2580
# Observación [-0.9562852   0.01973666]
# Accion 2590
# Observación [-0.6367714   0.03987739]
# Accion 2600
# Observación [-0.25570074  0.03119612]
# Accion 2610
# Observación [-0.05909454  0.0110076 ]
# Accion 2620
# Observación [-0.0692108  -0.00975195]
# Accion 2630
# Observación [-0.315492   -0.03655528]
# Accion 2640
# Observación [-0.73058146 -0.03911093]
# Accion 2650
# Observación [-1.0163584  -0.01693498]
# Accion 2660
# Observación [-1.0845677   0.00197376]
# Accion 2670
# Observación [-0.91008323  0.02969208]
# Accion 2680
# Observación [-0.49556282  0.04682413]
# Accion 2690
# Observación [-0.09125813  0.0279687 ]
# Accion 2700
# Observación [0.05261778 0.00320732]
# Accion 2710
# Observación [-0.03158843 -0.01763113]
# Accion 2720
# Observación [-0.30411652 -0.03488752]
# Accion 2730
# Observación [-0.69539475 -0.03695217]
# Accion 2740
# Observación [-0.95833164 -0.01651082]
# Accion 2750
# Observación [-1.0053147   0.00416582]
# Accion 2760
# Observación [-0.84620386  0.0249167 ]
# Accion 2770
# Observación [-0.5110141   0.03843096]
# Accion 2780
# Observación [-0.19784477  0.02288765]
# Accion 2790
# Observación [-0.0954297  -0.00108133]
# Accion 2800
# Observación [-0.21786907 -0.02094757]
# Accion 2810
# Observación [-0.5225538  -0.03334199]
# Accion 2820
# Observación [-0.80565274 -0.02176529]
# Accion 2830
# Observación [-0.9054233  -0.00140755]
# Accion 2840
# Observación [-0.7759834   0.02297581]
# Accion 2850
# Observación [-0.49103564  0.03009012]
# Accion 2860
# Observación [-0.24746965  0.01834329]
# Accion 2870
# Observación [-0.1985573  -0.00497367]
# Accion 2880
# Observación [-0.36145064 -0.02488562]
# Accion 2890
# Observación [-0.64139915 -0.02760886]
# Accion 2900
# Observación [-0.84683543 -0.01332213]
# Accion 2910
# Observación [-0.84851056  0.01113248]
# Accion 2920
# Observación [-0.6419027   0.02767888]
# Accion 2930
# Observación [-0.34150875  0.02842409]
# Accion 2940
# Observación [-0.15924613  0.00903855]
# Accion 2950
# Observación [-0.17911267 -0.01453443]
# Accion 2960
# Observación [-0.44360507 -0.03254897]
# Accion 2970
# Observación [-0.7604824  -0.02990213]
# Accion 2980
# Observación [-0.93253404 -0.00713244]
# Accion 2990
# Observación [-0.85362566  0.02208966]
# Accion 3000
# Observación [-0.5477871   0.03383199]
# Accion 3010
# Observación [-0.21585567  0.02869407]
# Accion 3020
# Observación [-0.05360072  0.00565177]
# Accion 3030
# Observación [-0.14207697 -0.02069378]
# Accion 3040
# Observación [-0.46923977 -0.03899087]
# Accion 3050
# Observación [-0.83145696 -0.02867701]
# Accion 3060
# Observación [-9.6524471e-01  1.8914268e-04]
# Accion 3070
# Observación [-0.8066119   0.02811394]
# Accion 3080
# Observación [-0.42683285  0.04051251]
# Accion 3090
# Observación [-0.09283105  0.0235811 ]
# Accion 3100
# Observación [0.01734551 0.00079099]
# Accion 3110
# Observación [-0.08502512 -0.02111594]
# Accion 3120
# Observación [-0.41506594 -0.04014269]
# Accion 3130
# Observación [-0.8096564 -0.033809 ]
# Accion 3140
# Observación [-1.0102612  -0.00897073]
# Accion 3150
# Observación [-0.9473815   0.01677173]
# Accion 3160
# Observación [-0.6712525   0.03450677]
# Accion 3170
# Observación [-0.30182034  0.03523491]
# Accion 3180
# Observación [-0.06732649  0.01318565]
# Accion 3190
# Observación [-0.07348904 -0.01356164]
# Accion 3200
# Observación [-0.3310699  -0.03488111]
# Accion 3210
# Observación [-0.7255061 -0.036907 ]
# Accion 3220
# Observación [-0.9982073  -0.01824919]
# Accion 3230
# Observación [-1.0136802   0.00868822]
# Accion 3240
# Observación [-0.7926669  0.0328964]
# Accion 3250
# Observación [-0.42050603  0.03834731]
# Accion 3260
# Observación [-0.10796493  0.02360065]
# Accion 3270
# Observación [-0.02366426 -0.00507231]
# Accion 3280
# Observación [-0.20979731 -0.02996836]
# Accion 3290
# Observación [-0.58661884 -0.03946232]
# Accion 3300
# Observación [-0.92578304 -0.02739411]
# Accion 3310
# Observación [-1.0695653  -0.00177214]
# Accion 3320
# Observación [-0.9332172   0.02604633]
# Accion 3330
# Observación [-0.5851942   0.04010971]
# Accion 3340
# Observación [-0.23415807  0.02853288]
# Accion 3350
# Observación [-0.05952708  0.00589667]
# Accion 3360
# Observación [-0.15009302 -0.02134011]
# Accion 3370
# Observación [-0.44172966 -0.03293819]
# Accion 3380
# Observación [-0.7557338  -0.02731951]
# Accion 3390
# Observación [-0.91255647 -0.0070653 ]
# Accion 3400
# Observación [-0.87606496  0.01394175]
# Accion 3410
# Observación [-0.63602376  0.03007089]
# Accion 3420
# Observación [-0.34057397  0.02736739]
# Accion 3430
# Observación [-0.17631134  0.00619035]
# Accion 3440
# Observación [-0.26072127 -0.02069436]
# Accion 3450
# Observación [-0.5524033  -0.03161418]
# Accion 3460
# Observación [-0.8030138 -0.0177318]
# Accion 3470
# Observación [-0.86723256  0.00397033]
# Accion 3480
# Observación [-0.7390753   0.02037838]
# Accion 3490
# Observación [-0.47438902  0.02892342]
# Accion 3500
# Observación [-0.2608019   0.01264195]
# Accion 3510
# Observación [-0.24755834 -0.00831452]
# Accion 3520
# Observación [-0.45551917 -0.02598375]
# Accion 3530
# Observación [-0.72284985 -0.02298708]
# Accion 3540
# Observación [-0.82178414  0.00282692]
# Accion 3550
# Observación [-0.6941648   0.02007107]
# Accion 3560
# Observación [-0.4562318   0.02601902]
# Accion 3570
# Observación [-0.2268934   0.01861185]
# Accion 3580
# Observación [-0.16977295 -0.00572501]
# Accion 3590
# Observación [-0.33129418 -0.02504962]
# Accion 3600
# Observación [-0.63362974 -0.02932213]
# Accion 3610
# Observación [-0.88130194 -0.01874388]
# Accion 3620
# Observación [-0.9370892   0.00556915]
# Accion 3630
# Observación [-0.75012404  0.02895768]
# Accion 3640
# Observación [-0.4196841   0.03365941]
# Accion 3650
# Observación [-0.17337526  0.01509262]
# Accion 3660
# Observación [-0.15056142 -0.0096559 ]
# Accion 3670
# Observación [-0.35953557 -0.02762146]
# Accion 3680
# Observación [-0.6777767  -0.03018175]
# Accion 3690
# Observación [-0.90668416 -0.0143403 ]
# Accion 3700
# Observación [-0.907735    0.01105143]
# Accion 3710
# Observación [-0.6778229   0.03006658]
# Accion 3720
# Observación [-0.3423921   0.03349907]
# Accion 3730
# Observación [-0.10689785  0.01423964]
# Accion 3740
# Observación [-0.11031292 -0.01294671]
# Accion 3750
# Observación [-0.35104823 -0.03313962]
# Accion 3760
# Observación [-0.7196358  -0.03686569]
# Accion 3770
# Observación [-1.0042874  -0.01819777]
# Accion 3780
# Observación [-1.039091    0.00976565]
# Accion 3790
# Observación [-0.8125475   0.03139532]
# Accion 3800
# Observación [-0.41646752  0.04051645]
# Accion 3810
# Observación [-0.13444452  0.01671292]
# Accion 3820
# Observación [-0.10260488 -0.00813485]
# Accion 3830
# Observación [-0.29939935 -0.02951189]
# Accion 3840
# Observación [-0.6417338  -0.03356064]
# Accion 3850
# Observación [-0.8853969  -0.01322168]
# Accion 3860
# Observación [-0.90042245  0.00766773]
# Accion 3870
# Observación [-0.7026352   0.03030056]
# Accion 3880
# Observación [-0.35233122  0.03412022]
# Accion 3890
# Observación [-0.11653612  0.01215934]
# Accion 3900
# Observación [-0.13989449 -0.01562152]
# Accion 3910
# Observación [-0.40478998 -0.03379506]
# Accion 3920
# Observación [-0.7609852  -0.03161618]
# Accion 3930
# Observación [-0.9304458  -0.00470828]
# Accion 3940
# Observación [-0.83521014  0.02003865]
# Accion 3950
# Observación [-0.54294276  0.03311291]
# Accion 3960
# Observación [-0.2504494   0.02139411]
# Accion 3970
# Observación [-0.15421388 -0.0005927 ]
# Accion 3980
# Observación [-0.2969106  -0.02515371]
# Accion 3990
# Observación [-0.6024697  -0.03090163]
# Accion 4000
# Observación [-0.8441816  -0.01604225]
# Accion 4010
# Observación [-0.89402705  0.00503514]
# Accion 4020
# Observación [-0.75101876  0.02136046]
# Accion 4030
# Observación [-0.4649952   0.03098197]
# Accion 4040
# Observación [-0.2102824   0.01810301]
# Accion 4050
# Observación [-0.1673921  -0.00871349]
# Accion 4060
# Observación [-0.35595486 -0.02542965]
# Accion 4070
# Observación [-0.63885784 -0.02639291]
# Accion 4080
# Observación [-0.824443  -0.0108309]
# Accion 4090
# Observación [-0.81429553  0.01144237]
# Accion 4100
# Observación [-0.6046639   0.02901594]
# Accion 4110
# Observación [-0.2919594   0.02755631]
# Accion 4120
# Observación [-0.10623231  0.00990903]
# Accion 4130
# Observación [-0.14163052 -0.01391159]
# Accion 4140
# Observación [-0.4059738  -0.03724241]
# Accion 4150
# Observación [-0.75692147 -0.03101704]
# Accion 4160
# Observación [-0.94753975 -0.0102338 ]
# Accion 4170
# Observación [-0.89375174  0.01764052]
# Accion 4180
# Observación [-0.6330501   0.03317601]
# Accion 4190
# Observación [-0.2779709   0.03352038]
# Accion 4200
# Observación [-0.04472129  0.01370862]
# Accion 4210
# Observación [-0.04567592 -0.01222205]
# Accion 4220
# Observación [-0.3119491  -0.03420603]
# Accion 4230
# Observación [-0.70195824 -0.04005061]
# Accion 4240
# Observación [-1.0114995 -0.0197215]
# Accion 4250
# Observación [-1.0655187  0.0042224]
# Accion 4260
# Observación [-0.9134419   0.02692799]
# Accion 4270
# Observación [-0.5502433  0.0404396]
# Accion 4280
# Observación [-0.18862687  0.02924735]
# Accion 4290
# Observación [-0.00570101  0.00844616]
# Accion 4300
# Observación [-0.07759959 -0.01847733]
# Accion 4310
# Observación [-0.38610205 -0.03628102]
# Accion 4320
# Observación [-0.74258554 -0.03024414]
# Accion 4330
# Observación [-0.96810013 -0.01253625]
# Accion 4340
# Observación [-0.92906696  0.01482207]
# Accion 4350
# Observación [-0.67297673  0.03317767]
# Accion 4360
# Observación [-0.32829306  0.03056403]
# Accion 4370
# Observación [-0.11601108  0.01095825]
# Accion 4380
# Observación [-0.13936484 -0.01280323]
# Accion 4390
# Observación [-0.38810542 -0.03454693]
# Accion 4400
# Observación [-0.746273   -0.03252971]
# Accion 4410
# Observación [-0.9615927  -0.01069695]
# Accion 4420
# Observación [-0.94526714  0.01270696]
# Accion 4430
# Observación [-0.6788244  0.0357132]
# Accion 4440
# Observación [-0.30206355  0.03558724]
# Accion 4450
# Observación [-0.03860464  0.01417268]
# Accion 4460
# Observación [-0.03507297 -0.01078593]
# Accion 4470
# Observación [-0.27030483 -0.03373128]
# Accion 4480
# Observación [-0.65122455 -0.03984585]
# Accion 4490
# Observación [-0.9481469  -0.01894583]
# Accion 4500
# Observación [-1.0050547  0.0046575]
# Accion 4510
# Observación [-0.82451737  0.02922312]
# Accion 4520
# Observación [-0.4543908   0.04017136]
# Accion 4530
# Observación [-0.11292475  0.02561944]
# Accion 4540
# Observación [0.02267627 0.00494745]
# Accion 4550
# Observación [-0.09997698 -0.02592448]
# Accion 4560
# Observación [-0.45338622 -0.04052386]
# Accion 4570
# Observación [-0.8356825  -0.03406024]
# Accion 4580
# Observación [-1.0390617  -0.00753619]
# Accion 4590
# Observación [-0.9909746   0.01743612]
# Accion 4600
# Observación [-0.6833316   0.03929349]
# Accion 4610
# Observación [-0.27930036  0.03641854]
# Accion 4620
# Observación [-0.02425412  0.01435685]
# Accion 4630
# Observación [ 0.00197916 -0.00861341]
# Accion 4640
# Observación [-0.19362597 -0.02979257]
# Accion 4650
# Observación [-0.5710656  -0.04137187]
# Accion 4660
# Observación [-0.9310312  -0.02874244]
# Accion 4670
# Observación [-1.0888319  -0.00408291]
# Accion 4680
# Observación [-0.97992605  0.02179636]
# Accion 4690
# Observación [-0.6325214   0.04227769]
# Accion 4700
# Observación [-0.22481562  0.03440711]
# Accion 4710
# Observación [-0.0146584   0.01019923]
# Accion 4720
# Observación [-0.04711035 -0.01477996]
# Accion 4730
# Observación [-0.32525334 -0.03654443]
# Accion 4740
# Observación [-0.72246987 -0.03678335]
# Accion 4750
# Observación [-0.9636504  -0.01350783]
# Accion 4760
# Observación [-0.9777455   0.01009712]
# Accion 4770
# Observación [-0.72667164  0.03572686]
# Accion 4780
# Observación [-0.33308625  0.03986933]
# Accion 4790
# Observación [-0.04886073  0.01727182]
# Accion 4800
# Observación [-0.00719972 -0.0056805 ]
# Accion 4810
# Observación [-0.19605985 -0.02674008]
# Accion 4820
# Observación [-0.5575721  -0.03979271]
# Accion 4830
# Observación [-0.9209432  -0.02678616]
# Accion 4840
# Observación [-1.0542419  -0.00223664]
# Accion 4850
# Observación [-0.9583518  0.018643 ]
# Accion 4860
# Observación [-0.61659855  0.04344914]
# Accion 4870
# Observación [-0.17929976  0.03893828]
# Accion 4880
# Observación [0.09681834 0.01485326]
# Accion 4890
# Observación [ 0.14674246 -0.00310404]
# Accion 4900
# Observación [-0.01881605 -0.02890029]
# Accion 4910
# Observación [-0.46538088 -0.05303056]
# Accion 4920
# Observación [-0.9905454  -0.04508056]
# Accion 4930
# Observación [-1.1754885   0.01103326]
# Accion 4940
# Observación [-0.9156796   0.03632261]
# Accion 4950
# Observación [-0.46653482  0.04838781]
# Accion 4960
# Observación [-0.04960161  0.03194549]
# Accion 4970
# Observación [0.11702605 0.00547459]
# Accion 4980
# Observación [ 0.05852303 -0.01518154]
# Accion 4990
# Observación [-0.21058054 -0.03533044]
# Accion 5000
# Observación [-0.65445423 -0.04546568]
# Accion 5010
# Observación [-1.0424287  -0.03225324]
# Accion 5020
# Observación [-1.1942703  0.0044879]
# Accion 5030
# Observación [-1.0245926   0.02833574]
# Accion 5040
# Observación [-0.6222915  0.0483307]
# Accion 5050
# Observación [-0.1414529   0.04088481]
# Accion 5060
# Observación [0.13752986 0.01471276]
# Accion 5070
# Observación [ 0.16176648 -0.0072762 ]
# Accion 5080
# Observación [-0.04276233 -0.03102958]
# Accion 5090
# Observación [-0.4593414  -0.04777789]
# Accion 5100
# Observación [-0.9136596  -0.03770749]
# Accion 5110
# Observación [-1.1350226  -0.01023703]
# Accion 5120
# Observación [-1.1157235   0.01172396]
# Accion 5130
# Observación [-0.8679137   0.03311426]
# Accion 5140
# Observación [-0.45289078  0.04419997]
# Accion 5150
# Observación [-0.07525659  0.02774935]
# Accion 5160
# Observación [0.08621799 0.00407848]
# Accion 5170
# Observación [-0.00767888 -0.01938423]
# Accion 5180
# Observación [-0.32767656 -0.04267647]
# Accion 5190
# Observación [-0.77471596 -0.0432321 ]
# Accion 5200
# Observación [-1.1171434  -0.02554612]
# Accion 5210
# Observación [-1.160088    0.01337179]
# Accion 5220
# Observación [-0.8587381   0.04057695]
# Accion 5230
# Observación [-0.3944333   0.04851985]
# Accion 5240
# Observación [-0.02757347  0.02640146]
# Accion 5250
# Observación [ 0.08418179 -0.00122196]
# Accion 5260
# Observación [-0.059815 -0.024867]
# Accion 5270
# Observación [-0.43266317 -0.04612515]
# Accion 5280
# Observación [-0.8783839  -0.03796675]
# Accion 5290
# Observación [-1.1210957  -0.01275459]
# Accion 5300
# Observación [-1.1078597   0.01139889]
# Accion 5310
# Observación [-0.8601124   0.03578558]
# Accion 5320
# Observación [-0.4227691   0.04676621]
# Accion 5330
# Observación [-0.02814016  0.03180311]
# Accion 5340
# Observación [0.15403008 0.01067951]
# Accion 5350
# Observación [ 0.16473703 -0.00606032]
# Accion 5360
# Observación [ 0.00759115 -0.02356779]
# Accion 5370
# Observación [-0.35430852 -0.04544096]
# Accion 5380
# Observación [-0.82419294 -0.04328628]
# Accion 5390
# Observación [-1.1362457  -0.01967058]
# Accion 5400
# Observación [-1.1580566   0.01438406]
# Accion 5410
# Observación [-0.900241    0.03680186]
# Accion 5420
# Observación [-0.41622525  0.05084563]
# Accion 5430
# Observación [0.01018742 0.03300162]
# Accion 5440
# Observación [0.20141645 0.01171853]
# Accion 5450
# Observación [ 0.22692908 -0.00660825]
# Accion 5460
# Observación [ 0.02802704 -0.03056956]
# Accion 5470
# Observación [-0.4126373  -0.05352223]
# Accion 5480
# Observación [-0.9115441 -0.042135 ]
# Accion 5490
# Observación [-1.1987581  0.0012419]
# Accion 5500
# Observación [-1.051012    0.02582888]
# Accion 5510
# Observación [-0.6693206   0.04613354]
# Accion 5520
# Observación [-0.21298502  0.04180442]
# Accion 5530
# Observación [0.06242026 0.01606126]
# Accion 5540
# Observación [ 0.10158077 -0.00487784]
# Accion 5550
# Observación [-0.0842102  -0.02942156]
# Accion 5560
# Observación [-0.47807407 -0.04581087]
# Accion 5570
# Observación [-0.9189313  -0.04012626]
# Accion 5580
# Observación [-1.1664037  -0.01177576]
# Accion 5590
# Observación [-1.1480101   0.01236876]
# Accion 5600
# Observación [-0.88483995  0.03777901]
# Accion 5610
# Observación [-0.409091    0.04805616]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 19
#      16 action = env.action_space.sample()
#      17 # Ejecuta esa acción, lo que nos devuelve, un nuevo estado, una recompensa, booleana /
#      18 # que nos indica que ha alcanzado su objetivo e info debug
# ---> 19 observation, reward, done, truncated, info = env.step(action)
#      20 if done:
#      21     print("Episode finished after {} timesteps".format(t+1))
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:124, in TimeLimit.step(self, action)
#     111 def step(
#     112     self, action: ActType
#     113 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     114     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     115
#     116     Args:
#    (...)    122
#     123     """
# --> 124     observation, reward, terminated, truncated, info = self.env.step(action)
#     125     self._elapsed_steps += 1
#     127     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:392, in OrderEnforcing.step(self, action)
#     390 if not self._has_reset:
#     391     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 392 return super().step(action)
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:284, in PassiveEnvChecker.step(self, action)
#     282     return env_step_passive_checker(self.env, action)
#     283 else:
# --> 284     return self.env.step(action)
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:152, in MountainCarEnv.step(self, action)
#     150 self.state = (position, velocity)
#     151 if self.render_mode == "human":
# --> 152     self.render()
#     153 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     154 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File c:\Users\rns_2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:271, in MountainCarEnv.render(self)
#     269 if self.render_mode == "human":
#     270     pygame.event.pump()
# --> 271     self.clock.tick(self.metadata["render_fps"])
#     272     pygame.display.flip()
#     274 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
gym.__version__
# Out:
# '1.2.3'
