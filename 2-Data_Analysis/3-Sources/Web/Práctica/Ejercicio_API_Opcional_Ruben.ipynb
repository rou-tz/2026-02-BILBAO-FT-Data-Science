# %% [markdown]
# # **Ejercicio Opcional APIs**
#
# Trabajar con Excels y CSVs descargados está bien para empezar, pero en el mundo real los datos cambian constantemente. Las APIs sirven para conectar nuestro código en Python directamente a bases de datos externas y extraer información actualizada.
#
# Cada API tiene sus reglas. Algunas son de pago, otras requieren claves de acceso y todas organizan la información de manera distinta. Por eso, la principal habilidad al usar una API es leer su documentación. Vamos a usar la [PokéAPI](https://pokeapi.co/docs/v2), una base de datos pública y sin registro.

# %% [markdown]
# ## El Reto: Registro Civil de Kanto
#
# Tu trabajo es generar el Carnet de Identidad de los Pokémon que traen los entrenadores. Para ello no puedes fiarte de la memoria del entrenador, tienes que conectarte a la API, extraer los datos del Pokémon, limpiarlos y guardarlos y generar el documento de identidad.
#
# Tu primer cliente quiere registrar a su Pikachu.

# %% [markdown]
# ### Paso 1: La URL y la petición (requests.get)
#
# Para pedirle información a la API, necesitamos la dirección exacta. Esta URL se construye uniendo tres partes en este caso:
#
# 1. URL Base (https://pokeapi.co/api/v2/): La raíz de la API. Todas las peticiones empiezan aquí.
#
# 2. Endpoint (pokemon): La categoría de datos que estamos consultando.
#
# 3. Recurso (pikachu): La entrada exacta que queremos buscar dentro de esa categoría.
#
# Puedes revisar la documentación para identificar los endpoint y los recursos. También para comprobar la estructura en la que se guardan los datos, muy importante para luego extraer la verdadera información.

# %%
import requests
import pandas as pd

endpoint = "pokemon"
recurso = "pikachu"

url = f"https://pokeapi.co/api/v2/{endpoint}/{recurso}"
datos_pikachu = requests.get(url)

# %% [markdown]
# Usamos la función requests.get() para hacer la consulta. Esta función no nos da los datos inmediatamente, sino una respuesta. Puedes probar haciendo un print del tipo. Si el código de estado de esa respuesta es 200, significa que la conexión ha sido un éxito y podemos proceder a leer los datos.

# %%
# Comprobamos el código de estado (200 = OK, 404 = No encontrado)
print(type(datos_pikachu), datos_pikachu)
# Out:
# <class 'requests.models.Response'> <Response [200]>

# %% [markdown]
# ### Paso 2: Desempaquetar los datos (.json())
#
# La variable datos_pikachu de nuestro paso anterior contiene la respuesta del servidor, pero no los datos legibles. Para extraer la información real, usa el método .json() y guárdalo en una variable llamada json_pikachu.

# %%
json_pikachu = datos_pikachu.json()

# %% [markdown]
# Como ves, la API nos devuelve una cantidad absurda de información.
#
# Pero para nuestro Carnet de Identidad Pokémon, sólo necesitamos estos datos clave:
#
# 1. ID
#
# 2. Nombre
#
# 3. Tipo 1 y Tipo 2
#
# 4. Las 6 estadísticas base (HP, Ataque, Defensa, Ataque Especial, Defensa Especial, Velocidad)
#
# 5. Peso (weight) y Altura (height)
#
# 6. La imagen oficial del pokemon.
#
# 7. La descripción de su especie.
#
# 8. Una de sus habilidades.
#
# ### Paso 3: Pasando los datos a Pandas
#
# Nuestra herramienta de trabajo final es un DataFrame.
# Crea un DataFrame desde el json_pikachu, puedes usar el constructor propio de DataFrame o el método json_normalize() de pandas.
# Una vez lo hagás, haz un head().

# %%
df_pikachu = pd.json_normalize(json_pikachu)
df_pikachu.head()
# Out:
#                                            abilities  base_experience  \
# 0  [{'ability': {'name': 'static', 'url': 'https:...              112
#
#                                                forms  \
# 0  [{'name': 'pikachu', 'url': 'https://pokeapi.c...
#
#                                         game_indices  height  \
# 0  [{'game_index': 84, 'version': {'name': 'red',...       4
#
#                                           held_items  id  is_default  \
# 0  [{'item': {'name': 'oran-berry', 'url': 'https...  25        True
#
#                           location_area_encounters  \
# 0  https://pokeapi.co/api/v2/pokemon/25/encounters
#
#                                                moves  ...  \
# 0  [{'move': {'name': 'mega-punch', 'url': 'https...  ...
#
#   sprites.versions.generation-vii.icons.front_default  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites.versions.generation-vii.icons.front_female  \
# 0                                               None
#
#   sprites.versions.generation-vii.ultra-sun-ultra-moon.front_default  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.versions.generation-vii.ultra-sun-ultra-moon.front_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.versions.generation-vii.ultra-sun-ultra-moon.front_shiny  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.versions.generation-vii.ultra-sun-ultra-moon.front_shiny_female  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.versions.generation-viii.brilliant-diamond-shining-pearl.front_default  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites.versions.generation-viii.brilliant-diamond-shining-pearl.front_female  \
# 0                                               None
#
#   sprites.versions.generation-viii.icons.front_default  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.versions.generation-viii.icons.front_female
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [1 rows x 146 columns]

# %% [markdown]
# El problema de los datos anidados
#
# Si te fijas en la tabla que acabamos de generar, verás algo raro. Hay columnas (como abilities, stats o types) que en lugar de tener un valor simple como "60" o "Electric", tienen listas [...] o más diccionarios {...} metidos en la misma celda.
#
# ¿Por qué pasa esto? Porque el JSON original no es plano. Tiene una estructura de árbol: un Pokémon tiene una lista de estadísticas, y cada estadística tiene su propio nombre y valor.
#
# Trabajar con tablas que tienen listas dentro de sus celdas es una dolor para hacer cálculos o gráficos y es lo más normal cuando obtienes la información desde una API.

# %% [markdown]
# ### Paso 4: Crear una función de limpieza
#
# Como funcionario de Datos en Kanto, no vas a hacer este proceso a mano solo para Pikachu. Tendrás que procesar cientos de solicitudes.
#
# Crea la función procesar_pokemon(json_data). Esta función debe recibir el JSON crudo de cualquier Pokémon y devolver un diccionario limpio con las siguientes claves y condiciones:
#
# 1. id, nombre, habilidad, peso y altura.
#
# 2. tipo_1 y tipo_2. Si el Pokémon solo tiene un tipo, asígnale el valor None a tipo_2.
#
# 3. Una clave por cada una de las 6 estadísticas base (hp, attack, etc.).
#
# 4. El enlace de la imagen "front_default" del arte oficial que se encuentra dentro de sprites. Vas a tener que bucear bien dentro del diccionario para encontrarla.
#
# 5. La descripción de la especie del pokemon.
#
# Una vez lo tengas pruébalo para crear un DataFrame con todos los valores limpios de Pikachu.

# %%
def procesar_pokemon(json_data):
    pokemon_limpio = {
        'id': json_data['id'],
        'nombre': json_data['name'],
        'habilidad': json_data['abilities'][0]['ability']['name'],
        'peso': json_data['weight'],
        'altura': json_data['height']
        }
#Tipos    
    tipos = json_data['types']
    pokemon_limpio['tipo_1'] = tipos[0]['type']['name']
    pokemon_limpio['tipo_2'] = tipos[1]['type']['name'] if len(tipos) > 1 else None
#Stats  
    for stat in json_data['stats']:
        stat_name = stat['stat']['name']
        pokemon_limpio[stat_name] = stat['base_stat']
#Imagen oficial  
    pokemon_limpio['imagen_oficial'] = json_data['sprites']['other']['official-artwork']['front_default']

#Obtener la especie para la descripcion #Esto no tenia ni idea de como hacerlo, pero vale leyendo lo de abajo tiene sentido que no lo supiera.
#Lo dejo igualmente
    species_url = json_data['species']['url']
    species_response = requests.get(species_url)
    species_data = species_response.json()
    
    descripcion = species_data['flavor_text_entries'][0]['flavor_text'].replace('\n', ' ').replace('\f', ' ')
    pokemon_limpio['descripcion'] = descripcion
    
    return pokemon_limpio

# %%
response = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')
pikachu_json = response.json()

pikachu_limpio = procesar_pokemon(pikachu_json)

df_pikachu = pd.DataFrame([pikachu_limpio])
print(df_pikachu.T)
# Out:
#                                                                  0
# id                                                              25
# nombre                                                     pikachu
# habilidad                                                   static
# peso                                                            60
# altura                                                           4
# tipo_1                                                    electric
# tipo_2                                                        None
# hp                                                              35
# attack                                                          55
# defense                                                         40
# special-attack                                                  50
# special-defense                                                 50
# speed                                                           90
# imagen_oficial   https://raw.githubusercontent.com/PokeAPI/spri...
# descripcion      When several of these POKéMON gather, their el...

# %% [markdown]
# ### Paso 5 - La descripción de la especie y la habilidad.
#
# Si no te diste cuenta, te lo digo yo. Tanto la biografía de la especie como los detalles de su habilidad no vienen dentro del primer JSON. Lo que nos da la API en su lugar es un enlace (url).
#
# Esto es una práctica estándar en el diseño de APIs. Si el servidor nos mandara toda la biografía en todos los idiomas y el texto de cada habilidad de golpe, la descarga sería enorme y lentísima. Por eficiencia, las APIs te entregan los datos superficiales y te dejan enlaces para que hagas nuevas peticiones solo si realmente necesitas profundizar.
#
# Investiga tu JSON crudo o la documentación de la [PokéAPI](https://pokeapi.co/docs/v2) para encontrar dónde están escondidas esas URLs. Haz las nuevas requests, limpia los datos e introduce el texto de la biografía y de la habilidad en tu diccionario antes de pasarlo al DataFrame.

# %%
response = requests.get('https://pokeapi.co/api/v2/pokemon/pikachu')
json_data = response.json()

species_url = json_data['species']['url']
species_response = requests.get(species_url)
species_data = species_response.json()
    
descripcion = species_data['flavor_text_entries'][0]['flavor_text'].replace('\n', ' ').replace('\f', ' ')
descripcion
# Out:
# 'When several of these POKéMON gather, their electricity could build and cause lightning storms.'

# %% [markdown]
# ### Paso 6 - A crear el CIP!
#
# Este paso es el más sencillo. Si tienes tu DataFrame con los datos limpios y listos sólo tienes que rellenar los campos de la función de abajo y comprueba como el CIP de Pikachu ya está listo. Ahora el entrenador de Pikachu ya puede llevarlo al centro pokemon para que le atiendan gratis.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import requests
from io import BytesIO
import textwrap

def crear_carnet(nombre, pokedex_id, tipo_1, tipo_2, altura, peso, imagen, lista_stats, habilidad_nombre, habilidad_efecto, descripcion):
    """
    Genera un Carné de Identidad usando Matplotlib. Devuelve el objeto Figure.
    Agrupa absolutamente todo el texto en la columna central y elimina la fila inferior.
    """   
    fig = plt.figure(figsize=(14, 7))
    fig.suptitle(f"CARNET DE IDENTIDAD POKEMON: {nombre.upper()}", fontsize=18, fontweight='bold', y=0.95)
        
    grid = fig.add_gridspec(1, 3, width_ratios=[1, 1.3, 1.2])
   
    ax_img = fig.add_subplot(grid[0, 0])
    ax_img.axis('off')
    try:
        respuesta = requests.get(imagen)
        img = mpimg.imread(BytesIO(respuesta.content))
        ax_img.imshow(img)
    except:
        ax_img.text(0.5, 0.5, "Imagen no disponible", ha='center', va='center')
    
    ax_info = fig.add_subplot(grid[0, 1])
    ax_info.axis('off') 
    
    texto_tipo2 = tipo_2.capitalize() if tipo_2 else "-"
        
    ancho_columna = 45
    efecto_wrap = textwrap.fill(habilidad_efecto, width=ancho_columna)
    bio_wrap = textwrap.fill(descripcion, width=ancho_columna)
    
    info_text = (
        f"Nombre: {nombre.capitalize()}\n"
        f"No Pokedex: #{pokedex_id}\n"
        f"Tipo 1: {tipo_1.capitalize()}\n"
        f"Tipo 2: {texto_tipo2}\n"
        f"Altura: {altura/10:.1f} m\n"
        f"Peso: {peso/10:.1f} kg\n\n"
        f"Habilidad: {habilidad_nombre.capitalize()}\n"
        f"{efecto_wrap}\n\n"
        f"Biografia:\n"
        f"{bio_wrap}"
    )
        
    ax_info.text(0.0, 0.5, info_text, fontsize=12, linespacing=1.5, ha='left', va='center')
    
    ax_radar = fig.add_subplot(grid[0, 2], polar=True)
    
    categorias = ['PS', 'Ataque', 'Defensa', 'Atq. Esp.', 'Def. Esp.', 'Velocidad']
    N = len(categorias)
    
    valores = list(lista_stats) + [lista_stats[0]]
    angulos = [n / float(N) * 2 * np.pi for n in range(N)] + [0]
    
    ax_radar.set_theta_offset(np.pi / 2)
    ax_radar.set_theta_direction(-1)
    
    ax_radar.set_xticks(angulos[:-1])
    ax_radar.set_xticklabels(categorias, color='dimgrey', size=11)
    ax_radar.set_rlabel_position(0)
    
    ax_radar.plot(angulos, valores, linewidth=2, linestyle='solid', color='royalblue')
    ax_radar.fill(angulos, valores, color='skyblue', alpha=0.4)
    ax_radar.set_title("Estadisticas Base", size=13, color='black', pad=15)

    plt.tight_layout()
    
    return fig

# %%
#Rellena los campos con la información de tu Dataframe y ejecuta!
pika = pikachu_limpio
crear_carnet(
    nombre= pika['nombre'], #El nombre de tu pokemon
    pokedex_id= pika['id'], #Id del pokemon
    tipo_1= pika['tipo_1'], #Tipo 1 del pokemon
    tipo_2= pika['tipo_2'], #el tipo 2
    altura= pika['altura'], #La altura del pokemon    
    peso= pika['peso'], #Su peso
    imagen= pika['imagen_oficial'], #Su imagen
    lista_stats= (
        pika['hp'],
        pika['attack'],
        pika['defense'],
        pika['special-attack'],
        pika['special-defense'],
        pika['speed']
    ), #Sus stats
    habilidad_nombre= pika['habilidad'], #EL nombre de su habilidad
    habilidad_efecto= "", #La descripción del efecto
    descripcion= pika['descripcion'] #La descripción de la especie del pokemon
);

# %% [markdown]
# ### Paso 7 - Creando la base de datos de Kanto
#
# Hasta ahora has procesado Carnets de Identidad uno a uno. Pero el Registro Civil necesita digitalizar a los 151 Pokémon originales de la región de Kanto de una sola vez.
#
# Sabes como hacer requests a la API, ahora en vez de traerte los datos de un pokemon tienes que conseguir los de 151.
#
# Además, tienes una función para procesar los datos en bruto del json de un pokemon, asi que utilízala para convertir esos 151 json en un dataframe nuevo hecho y derecho con los 151 pokemon de kanto.

# %%
response = requests.get('https://pokeapi.co/api/v2/pokemon?limit=151')
poke_data = response.json()

df_pokemon = pd.DataFrame(poke_data['results'])
df_pokemon.head()

# Lista para almacenar los datos procesados de cada Pokémon
lista_pokemon = []

# Recorrer cada Pokémon en la lista
for poke in df_pokemon['name']:
    pokemon_limpio = procesar_pokemon(requests.get(f'https://pokeapi.co/api/v2/pokemon/{poke}').json())
    lista_pokemon.append(pokemon_limpio)

# %%
lista_pokemon
# Out:
# [{'id': 1,
#   'nombre': 'bulbasaur',
#   'habilidad': 'overgrow',
#   'peso': 69,
#   'altura': 7,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 45,
#   'attack': 49,
#   'defense': 49,
#   'special-attack': 65,
#   'special-defense': 65,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/1.png',
#   'descripcion': 'A strange seed was planted on its back at birth. The plant sprouts and grows with this POKéMON.'},
#  {'id': 2,
#   'nombre': 'ivysaur',
#   'habilidad': 'overgrow',
#   'peso': 130,
#   'altura': 10,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 60,
#   'attack': 62,
#   'defense': 63,
#   'special-attack': 80,
#   'special-defense': 80,
#   'speed': 60,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/2.png',
#   'descripcion': 'When the bulb on its back grows large, it appears to lose the ability to stand on its hind legs.'},
#  {'id': 3,
#   'nombre': 'venusaur',
#   'habilidad': 'overgrow',
#   'peso': 1000,
#   'altura': 20,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 80,
#   'attack': 82,
#   'defense': 83,
#   'special-attack': 100,
#   'special-defense': 100,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/3.png',
#   'descripcion': 'The plant blooms when it is absorbing solar energy. It stays on the move to seek sunlight.'},
#  {'id': 4,
#   'nombre': 'charmander',
#   'habilidad': 'blaze',
#   'peso': 85,
#   'altura': 6,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 39,
#   'attack': 52,
#   'defense': 43,
#   'special-attack': 60,
#   'special-defense': 50,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/4.png',
#   'descripcion': 'Obviously prefers hot places. When it rains, steam is said to spout from the tip of its tail.'},
#  {'id': 5,
#   'nombre': 'charmeleon',
#   'habilidad': 'blaze',
#   'peso': 190,
#   'altura': 11,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 58,
#   'attack': 64,
#   'defense': 58,
#   'special-attack': 80,
#   'special-defense': 65,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/5.png',
#   'descripcion': 'When it swings its burning tail, it elevates the temperature to unbearably high levels.'},
#  {'id': 6,
#   'nombre': 'charizard',
#   'habilidad': 'blaze',
#   'peso': 905,
#   'altura': 17,
#   'tipo_1': 'fire',
#   'tipo_2': 'flying',
#   'hp': 78,
#   'attack': 84,
#   'defense': 78,
#   'special-attack': 109,
#   'special-defense': 85,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/6.png',
#   'descripcion': 'Spits fire that is hot enough to melt boulders. Known to cause forest fires unintentionally.'},
#  {'id': 7,
#   'nombre': 'squirtle',
#   'habilidad': 'torrent',
#   'peso': 90,
#   'altura': 5,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 44,
#   'attack': 48,
#   'defense': 65,
#   'special-attack': 50,
#   'special-defense': 64,
#   'speed': 43,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/7.png',
#   'descripcion': 'After birth, its back swells and hardens into a shell. Powerfully sprays foam from its mouth.'},
#  {'id': 8,
#   'nombre': 'wartortle',
#   'habilidad': 'torrent',
#   'peso': 225,
#   'altura': 10,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 59,
#   'attack': 63,
#   'defense': 80,
#   'special-attack': 65,
#   'special-defense': 80,
#   'speed': 58,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/8.png',
#   'descripcion': 'Often hides in water to stalk unwary prey. For swimming fast, it moves its ears to maintain balance.'},
#  {'id': 9,
#   'nombre': 'blastoise',
#   'habilidad': 'torrent',
#   'peso': 855,
#   'altura': 16,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 79,
#   'attack': 83,
#   'defense': 100,
#   'special-attack': 85,
#   'special-defense': 105,
#   'speed': 78,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/9.png',
#   'descripcion': 'A brutal POKéMON with pressurized water jets on its shell. They are used for high speed tackles.'},
#  {'id': 10,
#   'nombre': 'caterpie',
#   'habilidad': 'shield-dust',
#   'peso': 29,
#   'altura': 3,
#   'tipo_1': 'bug',
#   'tipo_2': None,
#   'hp': 45,
#   'attack': 30,
#   'defense': 35,
#   'special-attack': 20,
#   'special-defense': 20,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/10.png',
#   'descripcion': '如果碰到牠頭上的觸角， 牠就會分泌強烈的臭味 來保護自己。'},
#  {'id': 11,
#   'nombre': 'metapod',
#   'habilidad': 'shed-skin',
#   'peso': 99,
#   'altura': 7,
#   'tipo_1': 'bug',
#   'tipo_2': None,
#   'hp': 50,
#   'attack': 20,
#   'defense': 55,
#   'special-attack': 25,
#   'special-defense': 25,
#   'speed': 30,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/11.png',
#   'descripcion': 'This POKéMON is vulnerable to attack while its shell is soft, exposing its weak and tender body.'},
#  {'id': 12,
#   'nombre': 'butterfree',
#   'habilidad': 'compound-eyes',
#   'peso': 320,
#   'altura': 11,
#   'tipo_1': 'bug',
#   'tipo_2': 'flying',
#   'hp': 60,
#   'attack': 45,
#   'defense': 50,
#   'special-attack': 90,
#   'special-defense': 80,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/12.png',
#   'descripcion': 'In battle, it flaps its wings at high speed to release highly toxic dust into the air.'},
#  {'id': 13,
#   'nombre': 'weedle',
#   'habilidad': 'shield-dust',
#   'peso': 32,
#   'altura': 3,
#   'tipo_1': 'bug',
#   'tipo_2': 'poison',
#   'hp': 40,
#   'attack': 35,
#   'defense': 30,
#   'special-attack': 20,
#   'special-defense': 20,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/13.png',
#   'descripcion': 'Often found in forests, eating leaves. It has a sharp venomous stinger on its head.'},
#  {'id': 14,
#   'nombre': 'kakuna',
#   'habilidad': 'shed-skin',
#   'peso': 100,
#   'altura': 6,
#   'tipo_1': 'bug',
#   'tipo_2': 'poison',
#   'hp': 45,
#   'attack': 25,
#   'defense': 50,
#   'special-attack': 25,
#   'special-defense': 25,
#   'speed': 35,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/14.png',
#   'descripcion': 'Almost incapable of moving, this POKéMON can only harden its shell to protect itself from predators.'},
#  {'id': 15,
#   'nombre': 'beedrill',
#   'habilidad': 'swarm',
#   'peso': 295,
#   'altura': 10,
#   'tipo_1': 'bug',
#   'tipo_2': 'poison',
#   'hp': 65,
#   'attack': 90,
#   'defense': 40,
#   'special-attack': 45,
#   'special-defense': 80,
#   'speed': 75,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/15.png',
#   'descripcion': 'It has three poisonous stingers on its forelegs and its tail. They are used to jab its enemy repeatedly.'},
#  {'id': 16,
#   'nombre': 'pidgey',
#   'habilidad': 'keen-eye',
#   'peso': 18,
#   'altura': 3,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 40,
#   'attack': 45,
#   'defense': 40,
#   'special-attack': 35,
#   'special-defense': 35,
#   'speed': 56,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/16.png',
#   'descripcion': 'A common sight in forests and woods. It flaps its wings at ground level to kick up blinding sand.'},
#  {'id': 17,
#   'nombre': 'pidgeotto',
#   'habilidad': 'keen-eye',
#   'peso': 300,
#   'altura': 11,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 63,
#   'attack': 60,
#   'defense': 55,
#   'special-attack': 50,
#   'special-defense': 50,
#   'speed': 71,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/17.png',
#   'descripcion': 'Very protective of its sprawling territorial area, this POKéMON will fiercely peck at any intruder.'},
#  {'id': 18,
#   'nombre': 'pidgeot',
#   'habilidad': 'keen-eye',
#   'peso': 395,
#   'altura': 15,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 83,
#   'attack': 80,
#   'defense': 75,
#   'special-attack': 70,
#   'special-defense': 70,
#   'speed': 101,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/18.png',
#   'descripcion': 'When hunting, it skims the surface of water at high speed to pick off unwary prey such as MAGIKARP.'},
#  {'id': 19,
#   'nombre': 'rattata',
#   'habilidad': 'run-away',
#   'peso': 35,
#   'altura': 3,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 30,
#   'attack': 56,
#   'defense': 35,
#   'special-attack': 25,
#   'special-defense': 35,
#   'speed': 72,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/19.png',
#   'descripcion': 'キバが２つ。とにかく\u3000なんでも かじってみる。１ぴき\u3000みつけたら ４０ぴきは\u3000そこに\u3000すんでるはず。'},
#  {'id': 20,
#   'nombre': 'raticate',
#   'habilidad': 'run-away',
#   'peso': 185,
#   'altura': 7,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 81,
#   'defense': 60,
#   'special-attack': 50,
#   'special-defense': 70,
#   'speed': 97,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/20.png',
#   'descripcion': 'Ses pattes arrière lui permettent de traverser les rivières. Il est toujours en quête de nourriture.'},
#  {'id': 21,
#   'nombre': 'spearow',
#   'habilidad': 'keen-eye',
#   'peso': 20,
#   'altura': 3,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 40,
#   'attack': 60,
#   'defense': 30,
#   'special-attack': 31,
#   'special-defense': 31,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/21.png',
#   'descripcion': 'It flaps its small wings busily to fly. Using its beak, it searches in grass for prey.'},
#  {'id': 22,
#   'nombre': 'fearow',
#   'habilidad': 'keen-eye',
#   'peso': 380,
#   'altura': 12,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 65,
#   'attack': 90,
#   'defense': 65,
#   'special-attack': 61,
#   'special-defense': 61,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/22.png',
#   'descripcion': 'With its huge and magnificent wings, it can keep aloft without ever having to land for rest.'},
#  {'id': 23,
#   'nombre': 'ekans',
#   'habilidad': 'intimidate',
#   'peso': 69,
#   'altura': 20,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 35,
#   'attack': 60,
#   'defense': 44,
#   'special-attack': 40,
#   'special-defense': 54,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/23.png',
#   'descripcion': 'Moves silently and stealthily. Eats the eggs of birds, such as PIDGEY and SPEAROW, whole.'},
#  {'id': 24,
#   'nombre': 'arbok',
#   'habilidad': 'intimidate',
#   'peso': 650,
#   'altura': 35,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 60,
#   'attack': 95,
#   'defense': 69,
#   'special-attack': 65,
#   'special-defense': 79,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/24.png',
#   'descripcion': 'It is rumored that the ferocious warning markings on its belly differ from area to area.'},
#  {'id': 25,
#   'nombre': 'pikachu',
#   'habilidad': 'static',
#   'peso': 60,
#   'altura': 4,
#   'tipo_1': 'electric',
#   'tipo_2': None,
#   'hp': 35,
#   'attack': 55,
#   'defense': 40,
#   'special-attack': 50,
#   'special-defense': 50,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/25.png',
#   'descripcion': 'When several of these POKéMON gather, their electricity could build and cause lightning storms.'},
#  {'id': 26,
#   'nombre': 'raichu',
#   'habilidad': 'static',
#   'peso': 300,
#   'altura': 8,
#   'tipo_1': 'electric',
#   'tipo_2': None,
#   'hp': 60,
#   'attack': 90,
#   'defense': 55,
#   'special-attack': 90,
#   'special-defense': 80,
#   'speed': 110,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/26.png',
#   'descripcion': 'Its long tail serves as a ground to protect itself from its own high-voltage power.'},
#  {'id': 27,
#   'nombre': 'sandshrew',
#   'habilidad': 'sand-veil',
#   'peso': 120,
#   'altura': 6,
#   'tipo_1': 'ground',
#   'tipo_2': None,
#   'hp': 50,
#   'attack': 75,
#   'defense': 85,
#   'special-attack': 20,
#   'special-defense': 30,
#   'speed': 40,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/27.png',
#   'descripcion': 'Burrows deep underground in arid locations far from water. It only emerges to hunt for food.'},
#  {'id': 28,
#   'nombre': 'sandslash',
#   'habilidad': 'sand-veil',
#   'peso': 295,
#   'altura': 10,
#   'tipo_1': 'ground',
#   'tipo_2': None,
#   'hp': 75,
#   'attack': 100,
#   'defense': 110,
#   'special-attack': 45,
#   'special-defense': 55,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/28.png',
#   'descripcion': 'Curls up into a spiny ball when threatened. It can roll while curled up to attack or escape.'},
#  {'id': 29,
#   'nombre': 'nidoran-f',
#   'habilidad': 'poison-point',
#   'peso': 70,
#   'altura': 4,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 47,
#   'defense': 52,
#   'special-attack': 40,
#   'special-defense': 40,
#   'speed': 41,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/29.png',
#   'descripcion': 'Although small, its venomous barbs render this POKéMON dangerous. The female has smaller horns.'},
#  {'id': 30,
#   'nombre': 'nidorina',
#   'habilidad': 'poison-point',
#   'peso': 200,
#   'altura': 8,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 70,
#   'attack': 62,
#   'defense': 67,
#   'special-attack': 55,
#   'special-defense': 55,
#   'speed': 56,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/30.png',
#   'descripcion': "The female's horn develops slowly. Prefers physical attacks such as clawing and biting."},
#  {'id': 31,
#   'nombre': 'nidoqueen',
#   'habilidad': 'poison-point',
#   'peso': 600,
#   'altura': 13,
#   'tipo_1': 'poison',
#   'tipo_2': 'ground',
#   'hp': 90,
#   'attack': 92,
#   'defense': 87,
#   'special-attack': 75,
#   'special-defense': 85,
#   'speed': 76,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/31.png',
#   'descripcion': 'Its hard scales provide strong protection. It uses its hefty bulk to execute powerful moves.'},
#  {'id': 32,
#   'nombre': 'nidoran-m',
#   'habilidad': 'poison-point',
#   'peso': 90,
#   'altura': 5,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 46,
#   'attack': 57,
#   'defense': 40,
#   'special-attack': 40,
#   'special-defense': 40,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/32.png',
#   'descripcion': 'Stiffens its ears to sense danger. The larger its horns, the more powerful its secreted venom.'},
#  {'id': 33,
#   'nombre': 'nidorino',
#   'habilidad': 'poison-point',
#   'peso': 195,
#   'altura': 9,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 61,
#   'attack': 72,
#   'defense': 57,
#   'special-attack': 55,
#   'special-defense': 55,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/33.png',
#   'descripcion': '神經質且容易發脾氣打架。 當體內的腎上腺素增加時， 毒素的濃度也會提升。'},
#  {'id': 34,
#   'nombre': 'nidoking',
#   'habilidad': 'poison-point',
#   'peso': 620,
#   'altura': 14,
#   'tipo_1': 'poison',
#   'tipo_2': 'ground',
#   'hp': 81,
#   'attack': 102,
#   'defense': 77,
#   'special-attack': 85,
#   'special-defense': 75,
#   'speed': 85,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/34.png',
#   'descripcion': "It uses its powerful tail in battle to smash, constrict, then break the prey's bones."},
#  {'id': 35,
#   'nombre': 'clefairy',
#   'habilidad': 'cute-charm',
#   'peso': 75,
#   'altura': 6,
#   'tipo_1': 'fairy',
#   'tipo_2': None,
#   'hp': 70,
#   'attack': 45,
#   'defense': 48,
#   'special-attack': 60,
#   'special-defense': 65,
#   'speed': 35,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/35.png',
#   'descripcion': 'Its magical and cute appeal has many admirers. It is rare and found only in certain areas.'},
#  {'id': 36,
#   'nombre': 'clefable',
#   'habilidad': 'cute-charm',
#   'peso': 400,
#   'altura': 13,
#   'tipo_1': 'fairy',
#   'tipo_2': None,
#   'hp': 95,
#   'attack': 70,
#   'defense': 73,
#   'special-attack': 95,
#   'special-defense': 90,
#   'speed': 60,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/36.png',
#   'descripcion': 'A timid fairy POKéMON that is rarely seen. It will run and hide the moment it senses people.'},
#  {'id': 37,
#   'nombre': 'vulpix',
#   'habilidad': 'flash-fire',
#   'peso': 99,
#   'altura': 6,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 38,
#   'attack': 41,
#   'defense': 40,
#   'special-attack': 50,
#   'special-defense': 65,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/37.png',
#   'descripcion': 'At the time of birth, it has just one tail. The tail splits from its tip as it grows older.'},
#  {'id': 38,
#   'nombre': 'ninetales',
#   'habilidad': 'flash-fire',
#   'peso': 199,
#   'altura': 11,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 73,
#   'attack': 76,
#   'defense': 75,
#   'special-attack': 81,
#   'special-defense': 100,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/38.png',
#   'descripcion': 'Very smart and very vengeful. Grabbing one of its many tails could result in a 1000-year curse.'},
#  {'id': 39,
#   'nombre': 'jigglypuff',
#   'habilidad': 'cute-charm',
#   'peso': 55,
#   'altura': 5,
#   'tipo_1': 'normal',
#   'tipo_2': 'fairy',
#   'hp': 115,
#   'attack': 45,
#   'defense': 20,
#   'special-attack': 45,
#   'special-defense': 25,
#   'speed': 20,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/39.png',
#   'descripcion': 'When its huge eyes light up, it sings a mysteriously soothing melody that lulls its enemies to sleep.'},
#  {'id': 40,
#   'nombre': 'wigglytuff',
#   'habilidad': 'cute-charm',
#   'peso': 120,
#   'altura': 10,
#   'tipo_1': 'normal',
#   'tipo_2': 'fairy',
#   'hp': 140,
#   'attack': 70,
#   'defense': 45,
#   'special-attack': 85,
#   'special-defense': 50,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/40.png',
#   'descripcion': 'The body is soft and rubbery. When angered, it will suck in air and inflate itself to an enormous size.'},
#  {'id': 41,
#   'nombre': 'zubat',
#   'habilidad': 'inner-focus',
#   'peso': 75,
#   'altura': 8,
#   'tipo_1': 'poison',
#   'tipo_2': 'flying',
#   'hp': 40,
#   'attack': 45,
#   'defense': 35,
#   'special-attack': 30,
#   'special-defense': 40,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/41.png',
#   'descripcion': '因為沒有眼珠所以看不見東西。 會從口中發出超音波 來探測周圍的狀況。'},
#  {'id': 42,
#   'nombre': 'golbat',
#   'habilidad': 'inner-focus',
#   'peso': 550,
#   'altura': 16,
#   'tipo_1': 'poison',
#   'tipo_2': 'flying',
#   'hp': 75,
#   'attack': 80,
#   'defense': 70,
#   'special-attack': 65,
#   'special-defense': 75,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/42.png',
#   'descripcion': 'Once it strikes, it will not stop draining energy from the victim even if it gets too heavy to fly.'},
#  {'id': 43,
#   'nombre': 'oddish',
#   'habilidad': 'chlorophyll',
#   'peso': 54,
#   'altura': 5,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 45,
#   'attack': 50,
#   'defense': 55,
#   'special-attack': 75,
#   'special-defense': 65,
#   'speed': 30,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/43.png',
#   'descripcion': 'During the day, it keeps its face buried in the ground. At night, it wanders around sowing its seeds.'},
#  {'id': 44,
#   'nombre': 'gloom',
#   'habilidad': 'chlorophyll',
#   'peso': 86,
#   'altura': 8,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 60,
#   'attack': 65,
#   'defense': 70,
#   'special-attack': 85,
#   'special-defense': 75,
#   'speed': 40,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/44.png',
#   'descripcion': "The fluid that oozes from its mouth isn't drool. It is a nectar that is used to attract prey."},
#  {'id': 45,
#   'nombre': 'vileplume',
#   'habilidad': 'chlorophyll',
#   'peso': 186,
#   'altura': 12,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 75,
#   'attack': 80,
#   'defense': 85,
#   'special-attack': 110,
#   'special-defense': 90,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/45.png',
#   'descripcion': 'It has the world’s largest petals. With every step, the petals shake out heavy clouds of toxic pollen.'},
#  {'id': 46,
#   'nombre': 'paras',
#   'habilidad': 'effect-spore',
#   'peso': 54,
#   'altura': 3,
#   'tipo_1': 'bug',
#   'tipo_2': 'grass',
#   'hp': 35,
#   'attack': 70,
#   'defense': 55,
#   'special-attack': 45,
#   'special-defense': 55,
#   'speed': 25,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/46.png',
#   'descripcion': 'Burrows to suck tree roots. The mushrooms on its back grow by draw\xad ing nutrients from the bug host.'},
#  {'id': 47,
#   'nombre': 'parasect',
#   'habilidad': 'effect-spore',
#   'peso': 295,
#   'altura': 10,
#   'tipo_1': 'bug',
#   'tipo_2': 'grass',
#   'hp': 60,
#   'attack': 95,
#   'defense': 80,
#   'special-attack': 60,
#   'special-defense': 80,
#   'speed': 30,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/47.png',
#   'descripcion': 'A host-parasite pair in which the parasite mushroom has taken over the host bug. Prefers damp places.'},
#  {'id': 48,
#   'nombre': 'venonat',
#   'habilidad': 'compound-eyes',
#   'peso': 300,
#   'altura': 10,
#   'tipo_1': 'bug',
#   'tipo_2': 'poison',
#   'hp': 60,
#   'attack': 55,
#   'defense': 50,
#   'special-attack': 40,
#   'special-defense': 55,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/48.png',
#   'descripcion': 'Lives in the shadows of tall trees where it eats insects. It is attracted by light at night.'},
#  {'id': 49,
#   'nombre': 'venomoth',
#   'habilidad': 'shield-dust',
#   'peso': 125,
#   'altura': 15,
#   'tipo_1': 'bug',
#   'tipo_2': 'poison',
#   'hp': 70,
#   'attack': 65,
#   'defense': 60,
#   'special-attack': 90,
#   'special-defense': 75,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/49.png',
#   'descripcion': 'The dustlike scales covering its wings are color-coded to indicate the kinds of poison it has.'},
#  {'id': 50,
#   'nombre': 'diglett',
#   'habilidad': 'sand-veil',
#   'peso': 8,
#   'altura': 2,
#   'tipo_1': 'ground',
#   'tipo_2': None,
#   'hp': 10,
#   'attack': 55,
#   'defense': 25,
#   'special-attack': 35,
#   'special-defense': 45,
#   'speed': 95,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/50.png',
#   'descripcion': '피부가 매우 얇아서 빛을 쪼이게 되면 혈액이 데워져 약해진다.'},
#  {'id': 51,
#   'nombre': 'dugtrio',
#   'habilidad': 'sand-veil',
#   'peso': 333,
#   'altura': 7,
#   'tipo_1': 'ground',
#   'tipo_2': None,
#   'hp': 35,
#   'attack': 100,
#   'defense': 50,
#   'special-attack': 50,
#   'special-defense': 70,
#   'speed': 120,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/51.png',
#   'descripcion': 'A team of DIGLETT triplets. It triggers huge earthquakes by burrowing 60 miles underground.'},
#  {'id': 52,
#   'nombre': 'meowth',
#   'habilidad': 'pickup',
#   'peso': 42,
#   'altura': 4,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 40,
#   'attack': 45,
#   'defense': 35,
#   'special-attack': 40,
#   'special-defense': 40,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/52.png',
#   'descripcion': 'It washes its face regularly to keep the coin on its forehead spotless. It doesn’t get along with Galarian Meowth.'},
#  {'id': 53,
#   'nombre': 'persian',
#   'habilidad': 'limber',
#   'peso': 320,
#   'altura': 10,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 70,
#   'defense': 60,
#   'special-attack': 65,
#   'special-defense': 65,
#   'speed': 115,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/53.png',
#   'descripcion': 'Although its fur has many admirers, it is tough to raise as a pet because of its fickle meanness.'},
#  {'id': 54,
#   'nombre': 'psyduck',
#   'habilidad': 'damp',
#   'peso': 196,
#   'altura': 8,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 50,
#   'attack': 52,
#   'defense': 48,
#   'special-attack': 65,
#   'special-defense': 50,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/54.png',
#   'descripcion': 'While lulling its enemies with its vacant look, this wily POKéMON will use psychokinetic powers.'},
#  {'id': 55,
#   'nombre': 'golduck',
#   'habilidad': 'damp',
#   'peso': 766,
#   'altura': 17,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 80,
#   'attack': 82,
#   'defense': 78,
#   'special-attack': 95,
#   'special-defense': 80,
#   'speed': 85,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/55.png',
#   'descripcion': 'Often seen swim\xad ming elegantly by lake shores. It is often mistaken for the Japanese monster, Kappa.'},
#  {'id': 56,
#   'nombre': 'mankey',
#   'habilidad': 'vital-spirit',
#   'peso': 280,
#   'altura': 5,
#   'tipo_1': 'fighting',
#   'tipo_2': None,
#   'hp': 40,
#   'attack': 80,
#   'defense': 35,
#   'special-attack': 35,
#   'special-defense': 45,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/56.png',
#   'descripcion': 'Extremely quick to anger. It could be docile one moment then thrashing away the next instant.'},
#  {'id': 57,
#   'nombre': 'primeape',
#   'habilidad': 'vital-spirit',
#   'peso': 320,
#   'altura': 10,
#   'tipo_1': 'fighting',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 105,
#   'defense': 60,
#   'special-attack': 60,
#   'special-defense': 70,
#   'speed': 95,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/57.png',
#   'descripcion': 'Always furious and tenacious to boot. It will not abandon chasing its quarry until it is caught.'},
#  {'id': 58,
#   'nombre': 'growlithe',
#   'habilidad': 'intimidate',
#   'peso': 190,
#   'altura': 7,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 70,
#   'defense': 45,
#   'special-attack': 70,
#   'special-defense': 50,
#   'speed': 60,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/58.png',
#   'descripcion': 'Very protective of its territory. It will bark and bite to repel intruders from its space.'},
#  {'id': 59,
#   'nombre': 'arcanine',
#   'habilidad': 'intimidate',
#   'peso': 1550,
#   'altura': 19,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 90,
#   'attack': 110,
#   'defense': 80,
#   'special-attack': 100,
#   'special-defense': 80,
#   'speed': 95,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/59.png',
#   'descripcion': 'A POKéMON that has been admired since the past for its beauty. It runs agilely as if on wings.'},
#  {'id': 60,
#   'nombre': 'poliwag',
#   'habilidad': 'water-absorb',
#   'peso': 124,
#   'altura': 6,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 40,
#   'attack': 50,
#   'defense': 40,
#   'special-attack': 40,
#   'special-defense': 40,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/60.png',
#   'descripcion': 'Its newly grown legs prevent it from running. It appears to prefer swimming than trying to stand.'},
#  {'id': 61,
#   'nombre': 'poliwhirl',
#   'habilidad': 'water-absorb',
#   'peso': 200,
#   'altura': 10,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 65,
#   'defense': 65,
#   'special-attack': 50,
#   'special-defense': 50,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/61.png',
#   'descripcion': 'Capable of living in or out of water. When out of water, it sweats to keep its body slimy.'},
#  {'id': 62,
#   'nombre': 'poliwrath',
#   'habilidad': 'water-absorb',
#   'peso': 540,
#   'altura': 13,
#   'tipo_1': 'water',
#   'tipo_2': 'fighting',
#   'hp': 90,
#   'attack': 95,
#   'defense': 95,
#   'special-attack': 70,
#   'special-defense': 90,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/62.png',
#   'descripcion': 'An adept swimmer at both the front crawl and breast stroke. Easily overtakes the best human swimmers.'},
#  {'id': 63,
#   'nombre': 'abra',
#   'habilidad': 'synchronize',
#   'peso': 195,
#   'altura': 9,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 25,
#   'attack': 20,
#   'defense': 15,
#   'special-attack': 105,
#   'special-defense': 55,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/63.png',
#   'descripcion': 'Using its ability to read minds, it will identify impending danger and TELEPORT to safety.'},
#  {'id': 64,
#   'nombre': 'kadabra',
#   'habilidad': 'synchronize',
#   'peso': 565,
#   'altura': 13,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 40,
#   'attack': 35,
#   'defense': 30,
#   'special-attack': 120,
#   'special-defense': 70,
#   'speed': 105,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/64.png',
#   'descripcion': 'It emits special alpha waves from its body that induce headaches just by being close by.'},
#  {'id': 65,
#   'nombre': 'alakazam',
#   'habilidad': 'synchronize',
#   'peso': 480,
#   'altura': 15,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 50,
#   'defense': 45,
#   'special-attack': 135,
#   'special-defense': 95,
#   'speed': 120,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/65.png',
#   'descripcion': 'Its brain can out\xad perform a super\xad computer. Its intelligence quotient is said to be 5,000.'},
#  {'id': 66,
#   'nombre': 'machop',
#   'habilidad': 'guts',
#   'peso': 195,
#   'altura': 8,
#   'tipo_1': 'fighting',
#   'tipo_2': None,
#   'hp': 70,
#   'attack': 80,
#   'defense': 50,
#   'special-attack': 35,
#   'special-defense': 35,
#   'speed': 35,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/66.png',
#   'descripcion': 'Malgré sa petite taille, sa force lui permet de soulever plusieurs Racaillou à la fois.'},
#  {'id': 67,
#   'nombre': 'machoke',
#   'habilidad': 'guts',
#   'peso': 705,
#   'altura': 15,
#   'tipo_1': 'fighting',
#   'tipo_2': None,
#   'hp': 80,
#   'attack': 100,
#   'defense': 70,
#   'special-attack': 50,
#   'special-defense': 60,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/67.png',
#   'descripcion': 'Its muscular body is so powerful, it must wear a power save belt to be able to regulate its motions.'},
#  {'id': 68,
#   'nombre': 'machamp',
#   'habilidad': 'guts',
#   'peso': 1300,
#   'altura': 16,
#   'tipo_1': 'fighting',
#   'tipo_2': None,
#   'hp': 90,
#   'attack': 130,
#   'defense': 80,
#   'special-attack': 65,
#   'special-defense': 85,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/68.png',
#   'descripcion': 'Using its heavy muscles, it throws powerful punches that can send the victim clear over the horizon.'},
#  {'id': 69,
#   'nombre': 'bellsprout',
#   'habilidad': 'chlorophyll',
#   'peso': 40,
#   'altura': 7,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 50,
#   'attack': 75,
#   'defense': 35,
#   'special-attack': 70,
#   'special-defense': 30,
#   'speed': 40,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/69.png',
#   'descripcion': 'A carnivorous POKéMON that traps and eats bugs. It uses its root feet to soak up needed moisture.'},
#  {'id': 70,
#   'nombre': 'weepinbell',
#   'habilidad': 'chlorophyll',
#   'peso': 64,
#   'altura': 10,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 65,
#   'attack': 90,
#   'defense': 50,
#   'special-attack': 85,
#   'special-defense': 45,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/70.png',
#   'descripcion': 'It spits out POISONPOWDER to immobilize the enemy and then finishes it with a spray of ACID.'},
#  {'id': 71,
#   'nombre': 'victreebel',
#   'habilidad': 'chlorophyll',
#   'peso': 155,
#   'altura': 17,
#   'tipo_1': 'grass',
#   'tipo_2': 'poison',
#   'hp': 80,
#   'attack': 105,
#   'defense': 65,
#   'special-attack': 100,
#   'special-defense': 70,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/71.png',
#   'descripcion': 'Dieses Pokémon soll in großen Kolonien tief im Dschungel leben, doch niemand kann dies bestätigen.'},
#  {'id': 72,
#   'nombre': 'tentacool',
#   'habilidad': 'clear-body',
#   'peso': 455,
#   'altura': 9,
#   'tipo_1': 'water',
#   'tipo_2': 'poison',
#   'hp': 40,
#   'attack': 40,
#   'defense': 35,
#   'special-attack': 50,
#   'special-defense': 100,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/72.png',
#   'descripcion': 'Drifts in shallow seas. Anglers who hook them by accident are often punished by its stinging acid.'},
#  {'id': 73,
#   'nombre': 'tentacruel',
#   'habilidad': 'clear-body',
#   'peso': 550,
#   'altura': 16,
#   'tipo_1': 'water',
#   'tipo_2': 'poison',
#   'hp': 80,
#   'attack': 70,
#   'defense': 65,
#   'special-attack': 80,
#   'special-defense': 120,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/73.png',
#   'descripcion': 'The tentacles are normally kept short. On hunts, they are extended to ensnare and immobilize prey.'},
#  {'id': 74,
#   'nombre': 'geodude',
#   'habilidad': 'rock-head',
#   'peso': 200,
#   'altura': 4,
#   'tipo_1': 'rock',
#   'tipo_2': 'ground',
#   'hp': 40,
#   'attack': 80,
#   'defense': 100,
#   'special-attack': 30,
#   'special-defense': 30,
#   'speed': 20,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/74.png',
#   'descripcion': 'Found in fields and mountains. Mistaking them for boulders, people often step or trip on them.'},
#  {'id': 75,
#   'nombre': 'graveler',
#   'habilidad': 'rock-head',
#   'peso': 1050,
#   'altura': 10,
#   'tipo_1': 'rock',
#   'tipo_2': 'ground',
#   'hp': 55,
#   'attack': 95,
#   'defense': 115,
#   'special-attack': 45,
#   'special-defense': 45,
#   'speed': 35,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/75.png',
#   'descripcion': 'De naturaleza descuidada y libre, no le importa dañarse cuando baja rodando montañas.'},
#  {'id': 76,
#   'nombre': 'golem',
#   'habilidad': 'rock-head',
#   'peso': 3000,
#   'altura': 14,
#   'tipo_1': 'rock',
#   'tipo_2': 'ground',
#   'hp': 80,
#   'attack': 120,
#   'defense': 130,
#   'special-attack': 55,
#   'special-defense': 65,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/76.png',
#   'descripcion': 'Its boulder-like body is extremely hard. It can easily withstand dynamite blasts without damage.'},
#  {'id': 77,
#   'nombre': 'ponyta',
#   'habilidad': 'run-away',
#   'peso': 300,
#   'altura': 10,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 50,
#   'attack': 85,
#   'defense': 55,
#   'special-attack': 65,
#   'special-defense': 65,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/77.png',
#   'descripcion': 'Its hooves are 10 times harder than diamonds. It can trample anything completely flat in little time.'},
#  {'id': 78,
#   'nombre': 'rapidash',
#   'habilidad': 'run-away',
#   'peso': 950,
#   'altura': 17,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 100,
#   'defense': 70,
#   'special-attack': 80,
#   'special-defense': 80,
#   'speed': 105,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/78.png',
#   'descripcion': 'Galopa a casi 240 km por hora. Su crin ardiente parece una flecha cuando corre.'},
#  {'id': 79,
#   'nombre': 'slowpoke',
#   'habilidad': 'oblivious',
#   'peso': 360,
#   'altura': 12,
#   'tipo_1': 'water',
#   'tipo_2': 'psychic',
#   'hp': 90,
#   'attack': 65,
#   'defense': 65,
#   'special-attack': 40,
#   'special-defense': 40,
#   'speed': 15,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/79.png',
#   'descripcion': 'Descansa ocioso junto al agua. Si algo muerde su cola, no lo notará en todo el día.'},
#  {'id': 80,
#   'nombre': 'slowbro',
#   'habilidad': 'oblivious',
#   'peso': 785,
#   'altura': 16,
#   'tipo_1': 'water',
#   'tipo_2': 'psychic',
#   'hp': 95,
#   'attack': 75,
#   'defense': 110,
#   'special-attack': 100,
#   'special-defense': 80,
#   'speed': 30,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/80.png',
#   'descripcion': "The SHELLDER that is latched onto SLOWPOKE's tail is said to feed on the host's left over scraps."},
#  {'id': 81,
#   'nombre': 'magnemite',
#   'habilidad': 'magnet-pull',
#   'peso': 60,
#   'altura': 3,
#   'tipo_1': 'electric',
#   'tipo_2': 'steel',
#   'hp': 25,
#   'attack': 35,
#   'defense': 70,
#   'special-attack': 95,
#   'special-defense': 55,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/81.png',
#   'descripcion': 'Uses anti-gravity to stay suspended. Appears without warning and uses THUNDER WAVE and similar moves.'},
#  {'id': 82,
#   'nombre': 'magneton',
#   'habilidad': 'magnet-pull',
#   'peso': 600,
#   'altura': 10,
#   'tipo_1': 'electric',
#   'tipo_2': 'steel',
#   'hp': 50,
#   'attack': 60,
#   'defense': 95,
#   'special-attack': 120,
#   'special-defense': 70,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/82.png',
#   'descripcion': 'Formed by several MAGNEMITEs linked together. They frequently appear when sunspots flare up.'},
#  {'id': 83,
#   'nombre': 'farfetchd',
#   'habilidad': 'keen-eye',
#   'peso': 150,
#   'altura': 8,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 52,
#   'attack': 90,
#   'defense': 55,
#   'special-attack': 58,
#   'special-defense': 62,
#   'speed': 60,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/83.png',
#   'descripcion': 'The sprig of green onions it holds is its weapon. It is used much like a metal sword.'},
#  {'id': 84,
#   'nombre': 'doduo',
#   'habilidad': 'run-away',
#   'peso': 392,
#   'altura': 14,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 35,
#   'attack': 85,
#   'defense': 45,
#   'special-attack': 35,
#   'special-defense': 35,
#   'speed': 75,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/84.png',
#   'descripcion': 'A bird that makes up for its poor flying with its fast foot speed. Leaves giant footprints.'},
#  {'id': 85,
#   'nombre': 'dodrio',
#   'habilidad': 'run-away',
#   'peso': 852,
#   'altura': 18,
#   'tipo_1': 'normal',
#   'tipo_2': 'flying',
#   'hp': 60,
#   'attack': 110,
#   'defense': 70,
#   'special-attack': 60,
#   'special-defense': 60,
#   'speed': 110,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/85.png',
#   'descripcion': '由嘟嘟的某个头分裂 出的变种。以60千米的 时速在草原上奔跑。'},
#  {'id': 86,
#   'nombre': 'seel',
#   'habilidad': 'thick-fat',
#   'peso': 900,
#   'altura': 11,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 45,
#   'defense': 55,
#   'special-attack': 45,
#   'special-defense': 70,
#   'speed': 45,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/86.png',
#   'descripcion': 'The protruding horn on its head is very hard. It is used for bashing through thick ice.'},
#  {'id': 87,
#   'nombre': 'dewgong',
#   'habilidad': 'thick-fat',
#   'peso': 1200,
#   'altura': 17,
#   'tipo_1': 'water',
#   'tipo_2': 'ice',
#   'hp': 90,
#   'attack': 70,
#   'defense': 80,
#   'special-attack': 70,
#   'special-defense': 95,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/87.png',
#   'descripcion': 'Stores thermal energy in its body. Swims at a steady 8 knots even in intensely cold waters.'},
#  {'id': 88,
#   'nombre': 'grimer',
#   'habilidad': 'stench',
#   'peso': 300,
#   'altura': 9,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 80,
#   'attack': 80,
#   'defense': 50,
#   'special-attack': 40,
#   'special-defense': 50,
#   'speed': 25,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/88.png',
#   'descripcion': 'Appears in filthy areas. Thrives by sucking up polluted sludge that is pumped out of factories.'},
#  {'id': 89,
#   'nombre': 'muk',
#   'habilidad': 'stench',
#   'peso': 300,
#   'altura': 12,
#   'tipo_1': 'poison',
#   'tipo_2': None,
#   'hp': 105,
#   'attack': 105,
#   'defense': 75,
#   'special-attack': 65,
#   'special-defense': 100,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/89.png',
#   'descripcion': 'Thickly covered with a filthy, vile sludge. It is so toxic, even its footprints contain poison.'},
#  {'id': 90,
#   'nombre': 'shellder',
#   'habilidad': 'shell-armor',
#   'peso': 40,
#   'altura': 3,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 30,
#   'attack': 65,
#   'defense': 100,
#   'special-attack': 45,
#   'special-defense': 25,
#   'speed': 40,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/90.png',
#   'descripcion': 'Its hard shell repels any kind of attack. It is vulnerable only when its shell is open.'},
#  {'id': 91,
#   'nombre': 'cloyster',
#   'habilidad': 'shell-armor',
#   'peso': 1325,
#   'altura': 15,
#   'tipo_1': 'water',
#   'tipo_2': 'ice',
#   'hp': 50,
#   'attack': 95,
#   'defense': 180,
#   'special-attack': 85,
#   'special-defense': 45,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/91.png',
#   'descripcion': 'When attacked, it launches its horns in quick volleys. Its innards have never been seen.'},
#  {'id': 92,
#   'nombre': 'gastly',
#   'habilidad': 'levitate',
#   'peso': 1,
#   'altura': 13,
#   'tipo_1': 'ghost',
#   'tipo_2': 'poison',
#   'hp': 30,
#   'attack': 35,
#   'defense': 30,
#   'special-attack': 100,
#   'special-defense': 35,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/92.png',
#   'descripcion': 'Almost invisible, this gaseous POKéMON cloaks the target and puts it to sleep without notice.'},
#  {'id': 93,
#   'nombre': 'haunter',
#   'habilidad': 'levitate',
#   'peso': 1,
#   'altura': 16,
#   'tipo_1': 'ghost',
#   'tipo_2': 'poison',
#   'hp': 45,
#   'attack': 50,
#   'defense': 45,
#   'special-attack': 115,
#   'special-defense': 55,
#   'speed': 95,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/93.png',
#   'descripcion': 'Because of its ability to slip through block walls, it is said to be from an\xad other dimension.'},
#  {'id': 94,
#   'nombre': 'gengar',
#   'habilidad': 'cursed-body',
#   'peso': 405,
#   'altura': 15,
#   'tipo_1': 'ghost',
#   'tipo_2': 'poison',
#   'hp': 60,
#   'attack': 65,
#   'defense': 60,
#   'special-attack': 130,
#   'special-defense': 75,
#   'speed': 110,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/94.png',
#   'descripcion': 'Under a full moon, this POKéMON likes to mimic the shadows of people and laugh at their fright.'},
#  {'id': 95,
#   'nombre': 'onix',
#   'habilidad': 'rock-head',
#   'peso': 2100,
#   'altura': 88,
#   'tipo_1': 'rock',
#   'tipo_2': 'ground',
#   'hp': 35,
#   'attack': 45,
#   'defense': 160,
#   'special-attack': 30,
#   'special-defense': 45,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/95.png',
#   'descripcion': 'As it grows, the stone portions of its body harden to become similar to a diamond, but colored black.'},
#  {'id': 96,
#   'nombre': 'drowzee',
#   'habilidad': 'insomnia',
#   'peso': 324,
#   'altura': 10,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 60,
#   'attack': 48,
#   'defense': 45,
#   'special-attack': 43,
#   'special-defense': 90,
#   'speed': 42,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/96.png',
#   'descripcion': 'Puts enemies to sleep then eats their dreams. Occasionally gets sick from eating bad dreams.'},
#  {'id': 97,
#   'nombre': 'hypno',
#   'habilidad': 'insomnia',
#   'peso': 756,
#   'altura': 16,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 85,
#   'attack': 73,
#   'defense': 70,
#   'special-attack': 73,
#   'special-defense': 115,
#   'speed': 67,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/97.png',
#   'descripcion': 'When it locks eyes with an enemy, it will use a mix of PSI moves such as HYPNOSIS and CONFUSION.'},
#  {'id': 98,
#   'nombre': 'krabby',
#   'habilidad': 'hyper-cutter',
#   'peso': 65,
#   'altura': 4,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 30,
#   'attack': 105,
#   'defense': 90,
#   'special-attack': 25,
#   'special-defense': 25,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/98.png',
#   'descripcion': 'Its pincers are not only powerful weapons, they are used for balance when walking sideways.'},
#  {'id': 99,
#   'nombre': 'kingler',
#   'habilidad': 'hyper-cutter',
#   'peso': 600,
#   'altura': 13,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 130,
#   'defense': 115,
#   'special-attack': 50,
#   'special-defense': 50,
#   'speed': 75,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/99.png',
#   'descripcion': 'The large pincer has 10000 hp of crushing power. However, its huge size makes it unwieldy to use.'},
#  {'id': 100,
#   'nombre': 'voltorb',
#   'habilidad': 'soundproof',
#   'peso': 104,
#   'altura': 5,
#   'tipo_1': 'electric',
#   'tipo_2': None,
#   'hp': 40,
# ...
#   'habilidad': 'swift-swim',
#   'peso': 390,
#   'altura': 13,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 80,
#   'attack': 92,
#   'defense': 65,
#   'special-attack': 65,
#   'special-defense': 80,
#   'speed': 68,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/119.png',
#   'descripcion': 'In the autumn spawning season, they can be seen swimming powerfully up rivers and creeks.'},
#  {'id': 120,
#   'nombre': 'staryu',
#   'habilidad': 'illuminate',
#   'peso': 345,
#   'altura': 8,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 30,
#   'attack': 45,
#   'defense': 55,
#   'special-attack': 70,
#   'special-defense': 55,
#   'speed': 85,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/120.png',
#   'descripcion': 'If its body is torn, it can grow back if the red core remains. The core flashes at midnight.'},
#  {'id': 121,
#   'nombre': 'starmie',
#   'habilidad': 'illuminate',
#   'peso': 800,
#   'altura': 11,
#   'tipo_1': 'water',
#   'tipo_2': 'psychic',
#   'hp': 60,
#   'attack': 75,
#   'defense': 85,
#   'special-attack': 100,
#   'special-defense': 85,
#   'speed': 115,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/121.png',
#   'descripcion': 'Its central core glows with the seven colors of the rainbow. Some people value the core as a gem.'},
#  {'id': 122,
#   'nombre': 'mr-mime',
#   'habilidad': 'soundproof',
#   'peso': 545,
#   'altura': 13,
#   'tipo_1': 'psychic',
#   'tipo_2': 'fairy',
#   'hp': 40,
#   'attack': 45,
#   'defense': 65,
#   'special-attack': 100,
#   'special-defense': 120,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/122.png',
#   'descripcion': 'If interrupted while it is miming, it will slap around the offender with its broad hands.'},
#  {'id': 123,
#   'nombre': 'scyther',
#   'habilidad': 'swarm',
#   'peso': 560,
#   'altura': 15,
#   'tipo_1': 'bug',
#   'tipo_2': 'flying',
#   'hp': 70,
#   'attack': 110,
#   'defense': 80,
#   'special-attack': 55,
#   'special-defense': 80,
#   'speed': 105,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/123.png',
#   'descripcion': 'With ninja-like agility and speed, it can create the illusion that there is more than one.'},
#  {'id': 124,
#   'nombre': 'jynx',
#   'habilidad': 'oblivious',
#   'peso': 406,
#   'altura': 14,
#   'tipo_1': 'ice',
#   'tipo_2': 'psychic',
#   'hp': 65,
#   'attack': 50,
#   'defense': 35,
#   'special-attack': 115,
#   'special-defense': 95,
#   'speed': 95,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/124.png',
#   'descripcion': 'It seductively wiggles its hips as it walks. It can cause people to dance in unison with it.'},
#  {'id': 125,
#   'nombre': 'electabuzz',
#   'habilidad': 'static',
#   'peso': 300,
#   'altura': 11,
#   'tipo_1': 'electric',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 83,
#   'defense': 57,
#   'special-attack': 95,
#   'special-defense': 85,
#   'speed': 105,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/125.png',
#   'descripcion': 'Normally found near power plants, they can wander away and cause major blackouts in cities.'},
#  {'id': 126,
#   'nombre': 'magmar',
#   'habilidad': 'flame-body',
#   'peso': 445,
#   'altura': 13,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 95,
#   'defense': 57,
#   'special-attack': 100,
#   'special-defense': 85,
#   'speed': 93,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/126.png',
#   'descripcion': 'Its body always burns with an orange glow that enables it to hide perfectly among flames.'},
#  {'id': 127,
#   'nombre': 'pinsir',
#   'habilidad': 'hyper-cutter',
#   'peso': 550,
#   'altura': 15,
#   'tipo_1': 'bug',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 125,
#   'defense': 100,
#   'special-attack': 55,
#   'special-defense': 70,
#   'speed': 85,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/127.png',
#   'descripcion': 'If it fails to crush the victim in its pincers, it will swing it around and toss it hard.'},
#  {'id': 128,
#   'nombre': 'tauros',
#   'habilidad': 'intimidate',
#   'peso': 884,
#   'altura': 14,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 75,
#   'attack': 100,
#   'defense': 95,
#   'special-attack': 40,
#   'special-defense': 70,
#   'speed': 110,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/128.png',
#   'descripcion': 'When it targets an enemy, it charges furiously while whipping its body with its long tails.'},
#  {'id': 129,
#   'nombre': 'magikarp',
#   'habilidad': 'swift-swim',
#   'peso': 100,
#   'altura': 9,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 20,
#   'attack': 10,
#   'defense': 55,
#   'special-attack': 15,
#   'special-defense': 20,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/129.png',
#   'descripcion': 'In the distant past, it was somewhat stronger than the horribly weak descendants that exist today.'},
#  {'id': 130,
#   'nombre': 'gyarados',
#   'habilidad': 'intimidate',
#   'peso': 2350,
#   'altura': 65,
#   'tipo_1': 'water',
#   'tipo_2': 'flying',
#   'hp': 95,
#   'attack': 125,
#   'defense': 79,
#   'special-attack': 60,
#   'special-defense': 100,
#   'speed': 81,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/130.png',
#   'descripcion': 'Once it begins to rampage, a GYARADOS will burn everything down, even in a harsh storm.'},
#  {'id': 131,
#   'nombre': 'lapras',
#   'habilidad': 'water-absorb',
#   'peso': 2200,
#   'altura': 25,
#   'tipo_1': 'water',
#   'tipo_2': 'ice',
#   'hp': 130,
#   'attack': 85,
#   'defense': 80,
#   'special-attack': 85,
#   'special-defense': 95,
#   'speed': 60,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/131.png',
#   'descripcion': 'A POKéMON that has been over\xad hunted almost to extinction. It can ferry people across the water.'},
#  {'id': 132,
#   'nombre': 'ditto',
#   'habilidad': 'limber',
#   'peso': 40,
#   'altura': 3,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 48,
#   'attack': 48,
#   'defense': 48,
#   'special-attack': 48,
#   'special-defense': 48,
#   'speed': 48,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/132.png',
#   'descripcion': "Capable of copying an enemy's genetic code to instantly transform itself into a duplicate of the enemy."},
#  {'id': 133,
#   'nombre': 'eevee',
#   'habilidad': 'run-away',
#   'peso': 65,
#   'altura': 3,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 55,
#   'attack': 55,
#   'defense': 50,
#   'special-attack': 45,
#   'special-defense': 65,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/133.png',
#   'descripcion': 'Its genetic code is irregular. It may mutate if it is exposed to radiation from element STONEs.'},
#  {'id': 134,
#   'nombre': 'vaporeon',
#   'habilidad': 'water-absorb',
#   'peso': 290,
#   'altura': 10,
#   'tipo_1': 'water',
#   'tipo_2': None,
#   'hp': 130,
#   'attack': 65,
#   'defense': 60,
#   'special-attack': 110,
#   'special-defense': 95,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/134.png',
#   'descripcion': "Lives close to water. Its long tail is ridged with a fin which is often mistaken for a mermaid's."},
#  {'id': 135,
#   'nombre': 'jolteon',
#   'habilidad': 'volt-absorb',
#   'peso': 245,
#   'altura': 8,
#   'tipo_1': 'electric',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 65,
#   'defense': 60,
#   'special-attack': 110,
#   'special-defense': 95,
#   'speed': 130,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/135.png',
#   'descripcion': 'It accumulates negative ions in the atmosphere to blast out 10000- volt lightning bolts.'},
#  {'id': 136,
#   'nombre': 'flareon',
#   'habilidad': 'flash-fire',
#   'peso': 250,
#   'altura': 9,
#   'tipo_1': 'fire',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 130,
#   'defense': 60,
#   'special-attack': 95,
#   'special-defense': 110,
#   'speed': 65,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/136.png',
#   'descripcion': 'When storing thermal energy in its body, its temperature could soar to over 1600 degrees.'},
#  {'id': 137,
#   'nombre': 'porygon',
#   'habilidad': 'trace',
#   'peso': 365,
#   'altura': 8,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 65,
#   'attack': 60,
#   'defense': 70,
#   'special-attack': 85,
#   'special-defense': 75,
#   'speed': 40,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/137.png',
#   'descripcion': 'A POKéMON that consists entirely of programming code. Capable of moving freely in cyberspace.'},
#  {'id': 138,
#   'nombre': 'omanyte',
#   'habilidad': 'swift-swim',
#   'peso': 75,
#   'altura': 4,
#   'tipo_1': 'rock',
#   'tipo_2': 'water',
#   'hp': 35,
#   'attack': 40,
#   'defense': 100,
#   'special-attack': 90,
#   'special-defense': 55,
#   'speed': 35,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/138.png',
#   'descripcion': 'Although long extinct, in rare cases, it can be genetically resurrected from fossils.'},
#  {'id': 139,
#   'nombre': 'omastar',
#   'habilidad': 'swift-swim',
#   'peso': 350,
#   'altura': 10,
#   'tipo_1': 'rock',
#   'tipo_2': 'water',
#   'hp': 70,
#   'attack': 60,
#   'defense': 125,
#   'special-attack': 115,
#   'special-defense': 70,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/139.png',
#   'descripcion': 'A prehistoric POKéMON that died out when its heavy shell made it impossible to catch prey.'},
#  {'id': 140,
#   'nombre': 'kabuto',
#   'habilidad': 'swift-swim',
#   'peso': 115,
#   'altura': 5,
#   'tipo_1': 'rock',
#   'tipo_2': 'water',
#   'hp': 30,
#   'attack': 80,
#   'defense': 90,
#   'special-attack': 55,
#   'special-defense': 45,
#   'speed': 55,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/140.png',
#   'descripcion': 'A POKéMON that was resurrected from a fossil found in what was once the ocean floor eons ago.'},
#  {'id': 141,
#   'nombre': 'kabutops',
#   'habilidad': 'swift-swim',
#   'peso': 405,
#   'altura': 13,
#   'tipo_1': 'rock',
#   'tipo_2': 'water',
#   'hp': 60,
#   'attack': 115,
#   'defense': 105,
#   'special-attack': 65,
#   'special-defense': 70,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/141.png',
#   'descripcion': 'È un perfetto nuotatore. Taglia la preda con le sue falci e ne succhia il sangue.'},
#  {'id': 142,
#   'nombre': 'aerodactyl',
#   'habilidad': 'rock-head',
#   'peso': 590,
#   'altura': 18,
#   'tipo_1': 'rock',
#   'tipo_2': 'flying',
#   'hp': 80,
#   'attack': 105,
#   'defense': 65,
#   'special-attack': 60,
#   'special-defense': 75,
#   'speed': 130,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/142.png',
#   'descripcion': 'A Pokémon that roamed the skies in the dinosaur era. Its teeth are like saw blades.'},
#  {'id': 143,
#   'nombre': 'snorlax',
#   'habilidad': 'immunity',
#   'peso': 4600,
#   'altura': 21,
#   'tipo_1': 'normal',
#   'tipo_2': None,
#   'hp': 160,
#   'attack': 110,
#   'defense': 65,
#   'special-attack': 65,
#   'special-defense': 110,
#   'speed': 30,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/143.png',
#   'descripcion': 'Very lazy. Just eats and sleeps. As its rotund bulk builds, it becomes steadily more slothful.'},
#  {'id': 144,
#   'nombre': 'articuno',
#   'habilidad': 'pressure',
#   'peso': 554,
#   'altura': 17,
#   'tipo_1': 'ice',
#   'tipo_2': 'flying',
#   'hp': 90,
#   'attack': 85,
#   'defense': 100,
#   'special-attack': 95,
#   'special-defense': 125,
#   'speed': 85,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/144.png',
#   'descripcion': 'A legendary bird POKéMON that is said to appear to doomed people who are lost in icy mountains.'},
#  {'id': 145,
#   'nombre': 'zapdos',
#   'habilidad': 'pressure',
#   'peso': 526,
#   'altura': 16,
#   'tipo_1': 'electric',
#   'tipo_2': 'flying',
#   'hp': 90,
#   'attack': 90,
#   'defense': 85,
#   'special-attack': 125,
#   'special-defense': 90,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/145.png',
#   'descripcion': 'かみなりぐもの\u3000なかに\u3000いると いわれる\u3000でんせつの\u3000ポケモン。 カミナリを\u3000じざいに\u3000あやつる。'},
#  {'id': 146,
#   'nombre': 'moltres',
#   'habilidad': 'pressure',
#   'peso': 600,
#   'altura': 20,
#   'tipo_1': 'fire',
#   'tipo_2': 'flying',
#   'hp': 90,
#   'attack': 100,
#   'defense': 90,
#   'special-attack': 125,
#   'special-defense': 85,
#   'speed': 90,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/146.png',
#   'descripcion': 'Known as the legendary bird of fire. Every flap of its wings creates a dazzling flash of flames.'},
#  {'id': 147,
#   'nombre': 'dratini',
#   'habilidad': 'shed-skin',
#   'peso': 33,
#   'altura': 18,
#   'tipo_1': 'dragon',
#   'tipo_2': None,
#   'hp': 41,
#   'attack': 64,
#   'defense': 45,
#   'special-attack': 50,
#   'special-defense': 50,
#   'speed': 50,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/147.png',
#   'descripcion': 'Long considered a mythical POKéMON until recently when a small colony was found living underwater.'},
#  {'id': 148,
#   'nombre': 'dragonair',
#   'habilidad': 'shed-skin',
#   'peso': 165,
#   'altura': 40,
#   'tipo_1': 'dragon',
#   'tipo_2': None,
#   'hp': 61,
#   'attack': 84,
#   'defense': 65,
#   'special-attack': 70,
#   'special-defense': 70,
#   'speed': 70,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/148.png',
#   'descripcion': '人们相信它能操纵天气， 所以在哈克龙栖息的湖里， 供品总是源源不断。'},
#  {'id': 149,
#   'nombre': 'dragonite',
#   'habilidad': 'inner-focus',
#   'peso': 2100,
#   'altura': 22,
#   'tipo_1': 'dragon',
#   'tipo_2': 'flying',
#   'hp': 91,
#   'attack': 134,
#   'defense': 95,
#   'special-attack': 100,
#   'special-defense': 100,
#   'speed': 80,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/149.png',
#   'descripcion': 'An extremely rarely seen marine POKéMON. Its intelligence is said to match that of humans.'},
#  {'id': 150,
#   'nombre': 'mewtwo',
#   'habilidad': 'pressure',
#   'peso': 1220,
#   'altura': 20,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 106,
#   'attack': 110,
#   'defense': 90,
#   'special-attack': 154,
#   'special-defense': 90,
#   'speed': 130,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/150.png',
#   'descripcion': 'It was created by a scientist after years of horrific gene splicing and DNA engineering experiments.'},
#  {'id': 151,
#   'nombre': 'mew',
#   'habilidad': 'synchronize',
#   'peso': 40,
#   'altura': 4,
#   'tipo_1': 'psychic',
#   'tipo_2': None,
#   'hp': 100,
#   'attack': 100,
#   'defense': 100,
#   'special-attack': 100,
#   'special-defense': 100,
#   'speed': 100,
#   'imagen_oficial': 'https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/other/official-artwork/151.png',
#   'descripcion': 'So rare that it is still said to be a mirage by many experts. Only a few people have seen it worldwide.'}]

# %% [markdown]
# ### Paso 8 - EL último, ya acaba esto.
#
# Ahora que tienes tu DataFrame con todos los pokemon de Kanto. Escoge uno aleatorio y hazle un CIP con la función de antes. Copia la imagen o guárdala para subirla a Slack y todos puedan ver a qué pokémon le has hecho el CIP!

# %%
import random

pokemon_aleatorio = random.choice(lista_pokemon)

# %%
pika = pokemon_aleatorio
crear_carnet(
    nombre= pika['nombre'], #El nombre de tu pokemon
    pokedex_id= pika['id'], #Id del pokemon
    tipo_1= pika['tipo_1'], #Tipo 1 del pokemon
    tipo_2= pika['tipo_2'], #el tipo 2
    altura= pika['altura'], #La altura del pokemon    
    peso= pika['peso'], #Su peso
    imagen= pika['imagen_oficial'], #Su imagen
    lista_stats= (
        pika['hp'],
        pika['attack'],
        pika['defense'],
        pika['special-attack'],
        pika['special-defense'],
        pika['speed']
    ), #Sus stats
    habilidad_nombre= pika['habilidad'], #EL nombre de su habilidad
    habilidad_efecto= "", #La descripción del efecto
    descripcion= pika['descripcion'] #La descripción de la especie del pokemon
);
