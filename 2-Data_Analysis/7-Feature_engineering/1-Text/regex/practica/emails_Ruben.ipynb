# %% [markdown]
# # Extrae los dominios de los correos con una expresión regular

# %%
import re

emails = '''
miguellc@thebridgeschool.tech
miguel.cruz@uc3m.es
miguel-12-2000@mi-correo.net
miguellc@s@thebridgeschool.es
'''

# %% [markdown]
# Ejemplo:
# * @thebridgeschool.tech
# * @uc3m.es
# * @mi-correo.net
# * @thebridgeschool.es

# %%
# Regex para emails válidos y captura del dominio
pattern = r'^[\w\.-]+@([\w\.-]+\.\w+)$'

dominios = re.findall(pattern, emails, re.MULTILINE)

print(dominios)
# Out:
# ['thebridgeschool.tech', 'uc3m.es', 'mi-correo.net']
